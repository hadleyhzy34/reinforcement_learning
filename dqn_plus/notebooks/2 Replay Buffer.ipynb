# %% [markdown]
# # Replay Buffer

# %% [markdown]
# **目录：**
# 1. Basic Replay Buffer
#
# 2. Proportion-based Prioritized Experience Replay 分析
#
# 3. Rank-based Prioritized Experience Replay 分析
# ---
#
# 本节的重点内容在于如何分析，如何设计这些replay buffer，各种设计都有trade-off，所以并不是一定要按照此处的设计理念进行的

# %% [markdown]
# ## 1 Basic Replay Buffer
#
# ### 1) 功能分析
#
# 设计更为复杂的结构之前，我们从简单的结构开始，一个基础的Replay Buffer只需要能够实现三个基础的功能：
#   * 1. 记录新加入的transition
#   * 2. 忘记太久之前的transition
#   * 3. 从储存的记忆中抽样
#
# ### 2) 功能实现
#
# 这些功能都比较简单，只要我们将所有的transition储存在list中，就可以使用random.sample()函数就行抽样
#
# 至于遗忘以前的功能，可以使用deque数据结构自动遗忘，也可以选择覆盖list中已经存在的transition，这里我们选择第二种模式
#
# ### 3) 代码

# %%
import random
import torch
import numpy as np

class Replay_Buffer:
    '''
    Vanilla replay buffer
    '''
    
    def __init__(self, capacity=int(1e6), batch_size=None):
        
        self.capacity = capacity
        self.memory = [None for _ in range(capacity)] # save tuples (state, action, reward, next_state, done)
        self.ind_max = 0 # how many transitions have been stored
        
    def remember(self, state, action, reward, next_state, done):
        
        ind = self.ind_max % self.capacity
        self.memory[ind] = (state, action, reward, next_state, done)
        self.ind_max += 1
        
    def sample(self, k):
        '''
        return sampled transitions. Make sure that there are at least k transitions stored before calling this method 
        '''
        index_set = random.sample(list(range(len(self))), k)
        states = torch.from_numpy(np.vstack([self.memory[ind][0] for ind in index_set])).float()
        actions = torch.from_numpy(np.vstack([self.memory[ind][1] for ind in index_set])).long()
        rewards = torch.from_numpy(np.vstack([self.memory[ind][2] for ind in index_set])).float()
        next_states = torch.from_numpy(np.vstack([self.memory[ind][3] for ind in index_set])).float()
        dones = torch.from_numpy(np.vstack([self.memory[ind][4] for ind in index_set]).astype(np.uint8)).float()
        
        return states, actions, rewards, next_states, dones
    
    def __len__(self):
        return min(self.ind_max, self.capacity)

# %% [markdown]
# ## 2 Proportion-based Replay Buffer
#
# ### 1) 功能分析
#
# 除了之前的基础的功能，Proportion-based Replay Buffer还需要一个Sum Tree来记录和更新cumulative weight以进行快速采样，所以需要加入的新功能是：
#   * 1. 一个Sum Tree储存和更新每个transition的weight
#   * 2. 更新Sum Tree的方法
#
# ### 2) 功能实现
#
# 由于我们已经有了Sum Tree的实现方法，此处只要正确的使用即可。只需要再实现一个更新Sum Tree的方法即可
#
# 为了方便结合agent使用，应该尽量与基础的Replay Buffer类调用方式相同
#
# ### 3) 代码

# %%
class SumTree:
    
    def __init__(self, capacity):
        
        self.capacity = capacity
        # the first capacity-1 positions are not leaves
        self.vals = [0 for _ in range(2*capacity - 1)] # think about why if you are not familiar with this
        
    def retrive(self, num):
        '''
        This function find the first index whose cumsum is no smaller than num
        '''
        ind = 0 # search from root
        while ind < self.capacity-1: # not a leaf
            left = 2*ind + 1
            right = left + 1
            if num > self.vals[left]: # the sum of the whole left tree is not large enouth
                num -= self.vals[left] # think about why?
                ind = right
            else: # search in the left tree
                ind = left
        return ind - self.capacity + 1
    
    def update(self, delta, ind):
        '''
        Change the value at ind by delta, and update the tree
        Notice that this ind should be the index in real memory part, instead of the ind in self.vals
        '''
        ind += self.capacity - 1
        while True:
            self.vals[ind] += delta
            if ind == 0:
                break
            ind -= 1
            ind //= 2

# %%
EPSILON = 0.05
ALPHA = 0.5
TD_INIT = 1

class Proportion_Replay_Buffer:
    '''
    Proportion-based replay buffer
    '''
    
    def __init__(self, capacity=int(1e6), batch_size=None):
        self.capacity = capacity
        self.alpha = ALPHA
        self.memory = [None for _ in range(capacity)]
        self.weights = SumTree(self.capacity)
        self.default = TD_INIT
        self.ind_max = 0
        
    def remember(self, state, action, reward, next_state, done):
        index = self.ind_max % self.capacity
        self.memory[index] = (state, action, reward, next_state, done)
        delta = (self.default+EPSILON)**self.alpha - self.weights.vals[index+self.capacity-1]
        self.weights.update(delta, index)
        self.ind_max += 1
        
    def sample(self, batch_size):
        index_set = [self.weights.retrive(self.weights.vals[0]*random.random()) for _ in range(batch_size)]
        #print(index_set)
        probs = torch.from_numpy(np.vstack([self.weights.vals[ind+self.capacity-1]/self.weights.vals[0] for ind in index_set])).float()                     
        
        states = torch.from_numpy(np.vstack([self.memory[ind][0] for ind in index_set])).float()
        actions = torch.from_numpy(np.vstack([self.memory[ind][1] for ind in index_set])).long()
        rewards = torch.from_numpy(np.vstack([self.memory[ind][2] for ind in index_set])).float()
        next_states = torch.from_numpy(np.vstack([self.memory[ind][3] for ind in index_set])).float()
        dones = torch.from_numpy(np.vstack([self.memory[ind][4] for ind in index_set]).astype(np.uint8)).float()

        return index_set, states, actions, rewards, next_states, dones, probs
                                 
    def insert(self, error, index):
        delta = (error+EPSILON)**self.alpha - self.weights.vals[index+self.capacity-1]
        self.weights.update(delta, index)
            
    def __len__(self):
        return min(self.capacity, self.ind_max)

# %% [markdown]
# ## 3 Rank-based Replay Buffer
#
# ### 1) 功能分析
#
# 除了之前的基础的功能，Rank-based Replay Buffer还需要一个知道每个transition对应的TD-error的rank以调整weight，基于这个rank，还需要计算和储存分割点以进行论文中描述的抽样，大致需要的新功能有：
#   * 1. 对于所有transition TD-error及对应rank的储存
#   * 2. 更新rank所需要的方法
#
# ### 2) 功能实现
#
# 由于训练过程中会有大量的TD-error的变更，以及新加入的transition，想要快速更新rank，需要一直维持记录一个排好序的所有TD-error的序列，这样才能在$O(\log(n))$的时间内确定rank，否则每个新样本加入，每个训练后改变了TD-error的transition更新rank，都需要$O(n)$时间
#
# 在这样的一个有序TD-error的基础上，快速抽样的方法是在这个序列里抽样，再对应到具体的transition，此处有两种储存方式：
#   * 1. 将transition与TD-error一起储存到tuple中
#   * 2. 将transition储存在list中，将其index和TD-error一起储存到tuple中
#
# $$$$
# $$$$
# $$$$
# $$$$
# $$$$
# $$$$
# $$$$
# $$$$
# $$$$
# $$$$
# $$$$
# $$$$
# $$$$
# $$$$
# $$$$
# $$$$
# $$$$
# $$$$
# $$$$
# $$$$
# $$$$
# $$$$
#
# 此处我们选择第二种，因为我们其实需要一个transition $\longrightarrow$ rank的对应关系，不然当我们删除transition时，会需要$O(n)$时间寻找应该删除的rank和TD-error，所以没有必要将transition和它对应的TD-error对应起来。所以我们选择的储存方式是：
#   * 与之前的方式类似，建立一个list储存transition
#   * 建立另外的一个list，储存每个transition对应的rank
#   * 建立第三个list，储存(TD-error, transition index)的tuple
# 这样各种寻找都可以在$O(1)$时间完成
#
# 在此基础上，还需要考虑对rank的list，以及TD-error的list的处理，主要为删改处理，这个平均时间为O(n)
#
# ### 3) 代码
#
# 注意此处的代码并没有最优化，寻找进一步优化空间的任务当做同学们的作业

# %%
import bisect

class Rank_Replay_Buffer:
    '''
    Rank-based replay buffer
    '''
    
    def __init__(self, capacity=int(1e6), batch_size=64):
        self.capacity = capacity
        self.batch_size = batch_size
        self.alpha = ALPHA
        self.memory = [None for _ in range(capacity)]
        self.segments = [-1] + [None for _ in range(batch_size)] # the ith index will be in [segments[i-1]+1, segments[i]]
        
        self.errors = [] # saves (-TD_error, index of transition), sorted
        self.memory_to_rank = [None for _ in range(capacity)]
        
        self.ind_max = 0 # how many transitions have been stored
        self.total_weights = 0 # sum of p_i
        self.cumulated_weights = []
        
    def remember(self, state, action, reward, next_state, done):
        index = self.ind_max % self.capacity
        if self.ind_max >= self.capacity: # memory is full, need to pop
            self.pop(index)
        else: # memory is not full, need to adjust weights and find segment points
            self.total_weights += (1/(1+self.ind_max))**self.alpha # memory is not full, calculate new weights
            self.cumulated_weights.append(self.total_weights)
            self.update_segments()
        
        max_error = -self.errors[0][0] if self.errors else 0
        self.insert(max_error, index)
        self.memory[index] = (state, action, reward, next_state, done)
        self.ind_max += 1
        
    def sample(self, batch_size=None): # notive that batch_size is not used. It's just to unify the calling form
        index_set = [random.randint(self.segments[i]+1, self.segments[i+1]) for i in range(self.batch_size)]
        probs = torch.from_numpy(np.vstack([(1/(1+ind))**self.alpha/self.total_weights for ind in index_set])).float()
        
        index_set = [self.errors[ind][1] for ind in index_set]
        states = torch.from_numpy(np.vstack([self.memory[ind][0] for ind in index_set])).float()
        actions = torch.from_numpy(np.vstack([self.memory[ind][1] for ind in index_set])).long()
        rewards = torch.from_numpy(np.vstack([self.memory[ind][2] for ind in index_set])).float()
        next_states = torch.from_numpy(np.vstack([self.memory[ind][3] for ind in index_set])).float()
        dones = torch.from_numpy(np.vstack([self.memory[ind][4] for ind in index_set]).astype(np.uint8)).float()
        for ind in index_set:
            self.pop(ind)
        
        return index_set, states, actions, rewards, next_states, dones, probs
    
    def insert(self, error, index):
        '''
        Input : 
            error : the TD-error of this transition
            index : the location of this transition
        insert error into self.errors, update self.memory_to_rank and self.rank_to_memory accordingly
        '''
        ind = bisect.bisect(self.errors, (-error, index))
        self.memory_to_rank[index] = ind
        self.errors.insert(ind, (-error, index))
        for i in range(ind+1, len(self.errors)):
            self.memory_to_rank[self.errors[i][1]] += 1
        
    def pop(self, index):
        '''
        Input :
            index : the location of a transition
        remove this transition, update self.memory_to_rank and self.rank_to_memory accordingly
        '''
        ind = self.memory_to_rank[index]
        self.memory_to_rank[index] = None
        self.errors.pop(ind)
        for i in range(ind, len(self.errors)):
            self.memory_to_rank[self.errors[i][1]] -= 1
        
    def update_segments(self):
        '''
        Update the segment points.
        '''
        if self.ind_max+1 < self.batch_size: # if there is no enough transitions
            return None
        for i in range(self.batch_size):
            ind = bisect.bisect_left(self.cumulated_weights, self.total_weights*((i+1)/self.batch_size))
            self.segments[i+1] = max(ind, self.segments[i]+1)
            
    def __len__(self):
        return min(self.capacity, self.ind_max)

# %% [markdown]
# ## 4 Debug

# %%
states = np.random.standard_normal((11,5))
actions = np.random.randint(low=0, high=4, size=10).reshape(-1, 1)
rewards = np.random.rand(10, 1)
dones = np.array([random.random()<0.2 for _ in range(10)])

def get_transition(i):
    return states[i, :], actions[i], rewards[i], dones[i], states[i+1, :]

# %%
capacity = 7
batch_size = 3
N = 100

test = Proportion_Replay_Buffer(capacity=capacity, batch_size=batch_size)
for i in range(N):
    test.remember(*get_transition(i % 10))
    print('Episode {}'.format(i+1))
    print('Current errors are : {}'.format(test.weights.vals[capacity-1:]))
    if len(test) >= batch_size:
        temp_index, temp_states, temp_actions, temp_rewards, temp_next_states, temp_dones, temp_probs = test.sample(batch_size)
        temp_probs = temp_probs.numpy().reshape(-1)
        delta = [np.round(random.random(), 3) for _ in range(batch_size)]
        print('Sampled transitions {} with probs {}'.format(temp_index, temp_probs))
        print('Generated TD-error : {}'.format(delta))
        for ind, error in zip(temp_index, delta):
            test.insert(error, ind)
        print('=========================After updates========================')
        print('Current errors are : {}'.format(test.weights.vals[capacity-1:]))
    print()
# Out:
# Episode 1
# Current errors are : [1.05, 0, 0, 0, 0, 0, 0]
#
# Episode 2
# Current errors are : [1.05, 1.05, 0, 0, 0, 0, 0]
#
# Episode 3
# Current errors are : [1.05, 1.05, 1.05, 0, 0, 0, 0]
# Sampled transitions [1, 1, 0] with probs [0.33333334 0.33333334 0.33333334]
# Generated TD-error : [0.389, 0.187, 0.522]
# =========================After updates========================
# Current errors are : [0.5720000000000001, 0.237, 1.05, 0, 0, 0, 0]
#
# Episode 4
# Current errors are : [0.5720000000000001, 0.237, 1.05, 1.05, 0, 0, 0]
# Sampled transitions [0, 0, 2] with probs [0.19663115 0.19663115 0.36094877]
# Generated TD-error : [0.053, 0.985, 0.613]
# =========================After updates========================
# Current errors are : [1.035, 0.237, 0.663, 1.05, 0, 0, 0]
#
# Episode 5
# Current errors are : [1.035, 0.237, 0.663, 1.05, 1.05, 0, 0]
# Sampled transitions [1, 0, 2] with probs [0.05873606 0.25650558 0.16431227]
# Generated TD-error : [0.513, 0.054, 0.614]
# =========================After updates========================
# Current errors are : [0.10399999999999998, 0.5630000000000001, 0.664, 1.05, 1.05, 0, 0]
#
# Episode 6
# Current errors are : [0.10399999999999998, 0.5630000000000001, 0.664, 1.05, 1.05, 1.05, 0]
# Sampled transitions [5, 3, 4] with probs [0.2343227 0.2343227 0.2343227]
# Generated TD-error : [0.28, 0.239, 0.734]
# =========================After updates========================
# Current errors are : [0.10399999999999998, 0.5630000000000001, 0.664, 0.2889999999999999, 0.784, 0.33000000000000007, 0]
#
# Episode 7
# Current errors are : [0.10399999999999998, 0.5630000000000001, 0.664, 0.2889999999999999, 0.784, 0.33000000000000007, 1.05]
# Sampled transitions [6, 6, 1] with probs [0.27748415 0.27748415 0.14878435]
# Generated TD-error : [0.665, 0.747, 0.393]
# =========================After updates========================
# Current errors are : [0.10399999999999998, 0.443, 0.664, 0.2889999999999999, 0.784, 0.33000000000000007, 0.797]
#
# Episode 8
# Current errors are : [1.05, 0.443, 0.664, 0.2889999999999999, 0.784, 0.33000000000000007, 0.797]
# Sampled transitions [6, 2, 3] with probs [0.18292403 0.15239844 0.06633005]
# Generated TD-error : [0.457, 0.862, 0.722]
# =========================After updates========================
# Current errors are : [1.05, 0.443, 0.912, 0.772, 0.784, 0.33000000000000007, 0.507]
#
# Episode 9
# Current errors are : [1.05, 1.05, 0.912, 0.772, 0.784, 0.33000000000000007, 0.507]
# Sampled transitions [3, 6, 0] with probs [0.14283071 0.09380203 0.19426458]
# Generated TD-error : [0.733, 0.755, 0.66]
# =========================After updates========================
# Current errors are : [0.7100000000000001, 1.05, 0.912, 0.783, 0.784, 0.33000000000000007, 0.805]
#
# Episode 10
# Current errors are : [0.7100000000000001, 1.05, 1.05, 0.783, 0.784, 0.33000000000000007, 0.805]
# Sampled transitions [2, 2, 5] with probs [0.19049346 0.19049346 0.05986938]
# Generated TD-error : [0.052, 0.194, 0.318]
# =========================After updates========================
# Current errors are : [0.7100000000000001, 1.05, 0.244, 0.783, 0.784, 0.368, 0.805]
#
# Episode 11
# Current errors are : [0.7100000000000001, 1.05, 0.244, 1.05, 0.784, 0.368, 0.805]
# Sampled transitions [1, 1, 6] with probs [0.20953901 0.20953901 0.16064657]
# Generated TD-error : [0.258, 0.788, 0.093]
# =========================After updates========================
# Current errors are : [0.7100000000000001, 0.8380000000000001, 0.244, 1.05, 0.784, 0.368, 0.14300000000000002]
#
# Episode 12
# Current errors are : [0.7100000000000001, 0.8380000000000001, 0.244, 1.05, 1.05, 0.368, 0.14300000000000002]
# Sampled transitions [3, 4, 3] with probs [0.23847377 0.23847377 0.23847377]
# Generated TD-error : [0.176, 0.724, 0.449]
# =========================After updates========================
# Current errors are : [0.7100000000000001, 0.8380000000000001, 0.244, 0.499, 0.774, 0.368, 0.14300000000000002]
#
# Episode 13
# Current errors are : [0.7100000000000001, 0.8380000000000001, 0.244, 0.499, 0.774, 1.05, 0.14300000000000002]
# Sampled transitions [5, 1, 1] with probs [0.24659465 0.19680601 0.19680601]
# Generated TD-error : [0.381, 0.013, 0.923]
# =========================After updates========================
# Current errors are : [0.7100000000000001, 0.9730000000000001, 0.244, 0.499, 0.774, 0.43100000000000005, 0.14300000000000002]
#
# Episode 14
# Current errors are : [0.7100000000000001, 0.9730000000000001, 0.244, 0.499, 0.774, 0.43100000000000005, 1.05]
# Sampled transitions [0, 1, 0] with probs [0.151677   0.20786157 0.151677  ]
# Generated TD-error : [0.978, 0.196, 0.571]
# =========================After updates========================
# Current errors are : [0.621, 0.246, 0.244, 0.499, 0.774, 0.43100000000000005, 1.05]
#
# Episode 15
# Current errors are : [1.05, 0.246, 0.244, 0.499, 0.774, 0.43100000000000005, 1.05]
# Sampled transitions [2, 4, 3] with probs [0.05682347 0.18025151 0.11620867]
# Generated TD-error : [0.435, 0.973, 0.703]
# =========================After updates========================
# Current errors are : [1.05, 0.246, 0.485, 0.753, 1.023, 0.43100000000000005, 1.05]
#
# Episode 16
# Current errors are : [1.05, 1.05, 0.485, 0.753, 1.023, 0.43100000000000005, 1.05]
# Sampled transitions [4, 3, 5] with probs [0.17511126 0.12889421 0.0737761 ]
# Generated TD-error : [0.135, 0.236, 0.188]
# =========================After updates========================
# Current errors are : [1.05, 1.05, 0.485, 0.286, 0.18500000000000005, 0.238, 1.05]
#
# Episode 17
# Current errors are : [1.05, 1.05, 1.05, 0.286, 0.18500000000000005, 0.238, 1.05]
# Sampled transitions [0, 2, 2] with probs [0.21389285 0.21389285 0.21389285]
# Generated TD-error : [0.634, 0.931, 0.258]
# =========================After updates========================
# Current errors are : [0.684, 1.05, 0.30800000000000005, 0.286, 0.18500000000000005, 0.238, 1.05]
#
# Episode 18
# Current errors are : [0.684, 1.05, 0.30800000000000005, 1.05, 0.18500000000000005, 0.238, 1.05]
# Sampled transitions [2, 1, 3] with probs [0.06746988 0.23001096 0.23001096]
# Generated TD-error : [0.764, 0.402, 0.112]
# =========================After updates========================
# Current errors are : [0.684, 0.45199999999999996, 0.8140000000000001, 0.16200000000000003, 0.18500000000000005, 0.238, 1.05]
#
# Episode 19
# Current errors are : [0.684, 0.45199999999999996, 0.8140000000000001, 0.16200000000000003, 1.05, 0.238, 1.05]
# Sampled transitions [4, 2, 6] with probs [0.23595506 0.18292135 0.23595506]
# Generated TD-error : [0.383, 0.33, 0.48]
# =========================After updates========================
# Current errors are : [0.684, 0.45199999999999996, 0.38, 0.16200000000000003, 0.43300000000000005, 0.238, 0.53]
#
# Episode 20
# Current errors are : [0.684, 0.45199999999999996, 0.38, 0.16200000000000003, 0.43300000000000005, 1.05, 0.53]
# Sampled transitions [1, 1, 1] with probs [0.12246004 0.12246004 0.12246004]
# Generated TD-error : [0.801, 0.398, 0.256]
# =========================After updates========================
# Current errors are : [0.684, 0.306, 0.38, 0.16200000000000003, 0.43300000000000005, 1.05, 0.53]
#
# Episode 21
# Current errors are : [0.684, 0.306, 0.38, 0.16200000000000003, 0.43300000000000005, 1.05, 1.05]
# Sampled transitions [5, 0, 2] with probs [0.25830257 0.16826569 0.09348094]
# Generated TD-error : [0.3, 0.637, 0.406]
# =========================After updates========================
# Current errors are : [0.687, 0.306, 0.456, 0.16200000000000003, 0.43300000000000005, 0.35, 1.05]
#
# Episode 22
# Current errors are : [1.05, 0.306, 0.456, 0.16200000000000003, 0.43300000000000005, 0.35, 1.05]
# Sampled transitions [4, 0, 2] with probs [0.11373785 0.2758077  0.11977936]
# Generated TD-error : [0.977, 0.58, 0.096]
# =========================After updates========================
# Current errors are : [0.63, 0.306, 0.14600000000000002, 0.16200000000000003, 1.027, 0.35, 1.05]
#
# Episode 23
# Current errors are : [0.63, 1.05, 0.14600000000000002, 0.16200000000000003, 1.027, 0.35, 1.05]
# Sampled transitions [0, 6, 2] with probs [0.14269535 0.23782559 0.03306908]
# Generated TD-error : [0.515, 0.507, 0.626]
# =========================After updates========================
# Current errors are : [0.5650000000000001, 1.05, 0.676, 0.16200000000000003, 1.027, 0.35, 0.557]
#
# Episode 24
# Current errors are : [0.5650000000000001, 1.05, 1.05, 0.16200000000000003, 1.027, 0.35, 0.557]
# Sampled transitions [1, 4, 3] with probs [0.22054191 0.21571098 0.03402647]
# Generated TD-error : [0.356, 0.488, 0.917]
# =========================After updates========================
# Current errors are : [0.5650000000000001, 0.4059999999999999, 1.05, 0.9670000000000001, 0.538, 0.35, 0.557]
#
# Episode 25
# Current errors are : [0.5650000000000001, 0.4059999999999999, 1.05, 1.05, 0.538, 0.35, 0.557]
# Sampled transitions [2, 4, 3] with probs [0.23250665 0.11913197 0.23250665]
# Generated TD-error : [0.971, 0.388, 0.088]
# =========================After updates========================
# Current errors are : [0.5650000000000001, 0.4059999999999999, 1.021, 0.138, 0.438, 0.35, 0.557]
#
# Episode 26
# Current errors are : [0.5650000000000001, 0.4059999999999999, 1.021, 0.138, 1.05, 0.35, 0.557]
# Sampled transitions [2, 1, 6] with probs [0.24981649 0.09933937 0.13628578]
# Generated TD-error : [0.848, 0.016, 0.024]
# =========================After updates========================
# Current errors are : [0.5650000000000001, 0.066, 0.898, 0.138, 1.05, 0.35, 0.07400000000000001]
#
# Episode 27
# Current errors are : [0.5650000000000001, 0.066, 0.898, 0.138, 1.05, 1.05, 0.07400000000000001]
# Sampled transitions [5, 4, 0] with probs [0.2733663  0.2733663  0.14709711]
# Generated TD-error : [0.058, 0.063, 0.737]
# =========================After updates========================
# Current errors are : [0.787, 0.066, 0.898, 0.138, 0.11299999999999999, 0.10799999999999998, 0.07400000000000001]
#
# Episode 28
# Current errors are : [0.787, 0.066, 0.898, 0.138, 0.11299999999999999, 0.10799999999999998, 1.05]
# Sampled transitions [6, 1, 0] with probs [0.3322785  0.02088608 0.24905063]
# Generated TD-error : [0.114, 0.462, 0.246]
# =========================After updates========================
# Current errors are : [0.296, 0.512, 0.898, 0.138, 0.11299999999999999, 0.10799999999999998, 0.16400000000000003]
#
# Episode 29
# Current errors are : [1.05, 0.512, 0.898, 0.138, 0.11299999999999999, 0.10799999999999998, 0.16400000000000003]
# Sampled transitions [0, 0, 2] with probs [0.35199463 0.35199463 0.30103922]
# Generated TD-error : [0.872, 0.592, 0.805]
# =========================After updates========================
# Current errors are : [0.642, 0.512, 0.8550000000000001, 0.138, 0.11299999999999999, 0.10799999999999998, 0.16400000000000003]
#
# Episode 30
# Current errors are : [0.642, 1.05, 0.8550000000000001, 0.138, 0.11299999999999999, 0.10799999999999998, 0.16400000000000003]
# Sampled transitions [3, 1, 2] with probs [0.04495114 0.34201956 0.27850163]
# Generated TD-error : [0.536, 0.979, 0.067]
# =========================After updates========================
# Current errors are : [0.642, 1.029, 0.11699999999999999, 0.5860000000000001, 0.11299999999999999, 0.10799999999999998, 0.16400000000000003]
#
# Episode 31
# Current errors are : [0.642, 1.029, 1.05, 0.5860000000000001, 0.11299999999999999, 0.10799999999999998, 0.16400000000000003]
# Sampled transitions [2, 3, 6] with probs [0.2843987  0.15872157 0.04442037]
# Generated TD-error : [0.668, 0.166, 0.783]
# =========================After updates========================
# Current errors are : [0.642, 1.029, 0.7180000000000001, 0.21600000000000003, 0.11299999999999999, 0.10799999999999998, 0.8330000000000001]
#
# Episode 32
# Current errors are : [0.642, 1.029, 0.7180000000000001, 1.05, 0.11299999999999999, 0.10799999999999998, 0.8330000000000001]
# Sampled transitions [2, 6, 6] with probs [0.15980414 0.18539952 0.18539952]
# Generated TD-error : [0.461, 0.593, 0.612]
# =========================After updates========================
# Current errors are : [0.642, 1.029, 0.511, 1.05, 0.11299999999999999, 0.10799999999999998, 0.662]
#
# Episode 33
# Current errors are : [0.642, 1.029, 0.511, 1.05, 1.05, 0.10799999999999998, 0.662]
# Sampled transitions [1, 2, 3] with probs [0.2036817  0.10114806 0.20783848]
# Generated TD-error : [0.259, 0.389, 0.593]
# =========================After updates========================
# Current errors are : [0.642, 0.30899999999999994, 0.439, 0.643, 1.05, 0.10799999999999998, 0.662]
#
# Episode 34
# Current errors are : [0.642, 0.30899999999999994, 0.439, 0.643, 1.05, 1.05, 0.662]
# Sampled transitions [3, 6, 2] with probs [0.13409802 0.13806048 0.0915537 ]
# Generated TD-error : [0.826, 0.663, 0.165]
# =========================After updates========================
# Current errors are : [0.642, 0.30899999999999994, 0.21500000000000002, 0.876, 1.05, 1.05, 0.7130000000000001]
#
# Episode 35
# Current errors are : [0.642, 0.30899999999999994, 0.21500000000000002, 0.876, 1.05, 1.05, 1.05]
# Sampled transitions [0, 6, 5] with probs [0.12365177 0.20223421 0.20223421]
# Generated TD-error : [0.23, 0.495, 0.767]
# =========================After updates========================
# Current errors are : [0.28, 0.30899999999999994, 0.21500000000000002, 0.876, 1.05, 0.8170000000000001, 0.545]
#
# Episode 36
# Current errors are : [1.05, 0.30899999999999994, 0.21500000000000002, 0.876, 1.05, 0.8170000000000001, 0.545]
# Sampled transitions [5, 5, 6] with probs [0.16803785 0.16803785 0.11209379]
# Generated TD-error : [0.189, 0.895, 0.891]
# =========================After updates========================
# Current errors are : [1.05, 0.30899999999999994, 0.21500000000000002, 0.876, 1.05, 0.9450000000000001, 0.9410000000000001]
#
# Episode 37
# Current errors are : [1.05, 1.05, 0.21500000000000002, 0.876, 1.05, 0.9450000000000001, 0.9410000000000001]
# Sampled transitions [2, 5, 4] with probs [0.03509058 0.15423535 0.1713726 ]
# Generated TD-error : [0.909, 0.569, 0.444]
# =========================After updates========================
# Current errors are : [1.05, 1.05, 0.9590000000000001, 0.876, 0.494, 0.619, 0.9410000000000001]
#
# Episode 38
# Current errors are : [1.05, 1.05, 1.05, 0.876, 0.494, 0.619, 0.9410000000000001]
# Sampled transitions [0, 1, 0] with probs [0.17269737 0.17269737 0.17269737]
# Generated TD-error : [0.724, 0.765, 0.963]
# =========================After updates========================
# Current errors are : [1.013, 0.8150000000000001, 1.05, 0.876, 0.494, 0.619, 0.9410000000000001]
#
# Episode 39
# Current errors are : [1.013, 0.8150000000000001, 1.05, 1.05, 0.494, 0.619, 0.9410000000000001]
# Sampled transitions [3, 4, 1] with probs [0.17552657 0.08258107 0.13624206]
# Generated TD-error : [0.161, 0.818, 0.408]
# =========================After updates========================
# Current errors are : [1.013, 0.45799999999999996, 1.05, 0.21100000000000008, 0.868, 0.619, 0.9410000000000001]
#
# Episode 40
# Current errors are : [1.013, 0.45799999999999996, 1.05, 0.21100000000000008, 1.05, 0.619, 0.9410000000000001]
# Sampled transitions [2, 6, 0] with probs [0.1965556  0.17615126 0.18962935]
# Generated TD-error : [0.006, 0.1, 0.8]
# =========================After updates========================
# Current errors are : [0.8500000000000001, 0.45799999999999996, 0.05600000000000005, 0.21100000000000008, 1.05, 0.619, 0.15000000000000002]
#
# Episode 41
# Current errors are : [0.8500000000000001, 0.45799999999999996, 0.05600000000000005, 0.21100000000000008, 1.05, 1.05, 0.15000000000000002]
# Sampled transitions [1, 4, 5] with probs [0.11973856 0.27450982 0.27450982]
# Generated TD-error : [0.185, 0.34, 0.098]
# =========================After updates========================
# Current errors are : [0.8500000000000001, 0.235, 0.05600000000000005, 0.21100000000000008, 0.39, 0.14800000000000002, 0.15000000000000002]
#
# Episode 42
# Current errors are : [0.8500000000000001, 0.235, 0.05600000000000005, 0.21100000000000008, 0.39, 0.14800000000000002, 1.05]
# Sampled transitions [6, 6, 0] with probs [0.35714287 0.35714287 0.28911564]
# Generated TD-error : [0.685, 0.101, 0.891]
# =========================After updates========================
# Current errors are : [0.9410000000000001, 0.235, 0.05600000000000005, 0.21100000000000008, 0.39, 0.14800000000000002, 0.15100000000000002]
#
# Episode 43
# Current errors are : [1.05, 0.235, 0.05600000000000005, 0.21100000000000008, 0.39, 0.14800000000000002, 0.15100000000000002]
# Sampled transitions [3, 0, 0] with probs [0.0941544  0.46854082 0.46854082]
# Generated TD-error : [0.51, 0.562, 0.754]
# =========================After updates========================
# Current errors are : [0.804, 0.235, 0.05600000000000005, 0.56, 0.39, 0.14800000000000002, 0.15100000000000002]
#
# Episode 44
# Current errors are : [0.804, 1.05, 0.05600000000000005, 0.56, 0.39, 0.14800000000000002, 0.15100000000000002]
# Sampled transitions [1, 0, 3] with probs [0.33238366 0.2545109  0.17727129]
# Generated TD-error : [0.177, 0.85, 0.082]
# =========================After updates========================
# Current errors are : [0.9, 0.22699999999999998, 0.05600000000000005, 0.132, 0.39, 0.14800000000000002, 0.15100000000000002]
#
# Episode 45
# Current errors are : [0.9, 0.22699999999999998, 1.05, 0.132, 0.39, 0.14800000000000002, 0.15100000000000002]
# Sampled transitions [2, 3, 4] with probs [0.3502335  0.04402935 0.13008672]
# Generated TD-error : [0.46, 0.888, 0.768]
# =========================After updates========================
# Current errors are : [0.9, 0.22699999999999998, 0.51, 0.9380000000000001, 0.8180000000000001, 0.14800000000000002, 0.15100000000000002]
#
# Episode 46
# Current errors are : [0.9, 0.22699999999999998, 0.51, 1.05, 0.8180000000000001, 0.14800000000000002, 0.15100000000000002]
# Sampled transitions [3, 3, 4] with probs [0.27602524 0.27602524 0.21503681]
# Generated TD-error : [0.221, 0.956, 0.137]
# =========================After updates========================
# Current errors are : [0.9, 0.22699999999999998, 0.51, 1.006, 0.18700000000000006, 0.14800000000000002, 0.15100000000000002]
#
# Episode 47
# Current errors are : [0.9, 0.22699999999999998, 0.51, 1.006, 1.05, 0.14800000000000002, 0.15100000000000002]
# Sampled transitions [0, 3, 0] with probs [0.2254509 0.252004  0.2254509]
# Generated TD-error : [0.512, 0.492, 0.984]
# =========================After updates========================
# Current errors are : [1.034, 0.22699999999999998, 0.51, 0.542, 1.05, 0.14800000000000002, 0.15100000000000002]
#
# Episode 48
# Current errors are : [1.034, 0.22699999999999998, 0.51, 0.542, 1.05, 1.05, 0.15100000000000002]
# Sampled transitions [1, 3, 0] with probs [0.04973707 0.11875547 0.22655566]
# Generated TD-error : [0.645, 0.217, 0.73]
# =========================After updates========================
# Current errors are : [0.78, 0.6950000000000001, 0.51, 0.267, 1.05, 1.05, 0.15100000000000002]
#
# Episode 49
# Current errors are : [0.78, 0.6950000000000001, 0.51, 0.267, 1.05, 1.05, 1.05]
# Sampled transitions [1, 1, 1] with probs [0.12865606 0.12865606 0.12865606]
# Generated TD-error : [0.587, 0.732, 0.111]
# =========================After updates========================
# Current errors are : [0.78, 0.16100000000000003, 0.51, 0.267, 1.05, 1.05, 1.05]
#
# Episode 50
# Current errors are : [1.05, 0.16100000000000003, 0.51, 0.267, 1.05, 1.05, 1.05]
# Sampled transitions [0, 0, 4] with probs [0.20435968 0.20435968 0.20435968]
# Generated TD-error : [0.558, 0.58, 0.091]
# =========================After updates========================
# Current errors are : [0.63, 0.16100000000000003, 0.51, 0.267, 0.14100000000000001, 1.05, 1.05]
#
# Episode 51
# Current errors are : [0.63, 1.05, 0.51, 0.267, 0.14100000000000001, 1.05, 1.05]
# Sampled transitions [1, 5, 4] with probs [0.22349936 0.22349936 0.03001277]
# Generated TD-error : [0.727, 0.198, 0.396]
# =========================After updates========================
# Current errors are : [0.63, 0.777, 0.51, 0.267, 0.446, 0.248, 1.05]
#
# Episode 52
# Current errors are : [0.63, 0.777, 1.05, 0.267, 0.446, 0.248, 1.05]
# Sampled transitions [0, 6, 0] with probs [0.14100268 0.23500447 0.14100268]
# Generated TD-error : [0.226, 0.903, 0.891]
# =========================After updates========================
# Current errors are : [0.9410000000000001, 0.777, 1.05, 0.267, 0.446, 0.248, 0.9530000000000001]
#
# Episode 53
# Current errors are : [0.9410000000000001, 0.777, 1.05, 1.05, 0.446, 0.248, 0.9530000000000001]
# Sampled transitions [6, 1, 4] with probs [0.17438243 0.14217749 0.08161025]
# Generated TD-error : [0.543, 0.268, 0.072]
# =========================After updates========================
# Current errors are : [0.9410000000000001, 0.318, 1.05, 1.05, 0.122, 0.248, 0.5930000000000001]
#
# Episode 54
# Current errors are : [0.9410000000000001, 0.318, 1.05, 1.05, 1.05, 0.248, 0.5930000000000001]
# Sampled transitions [5, 4, 2] with probs [0.0472381 0.2       0.2      ]
# Generated TD-error : [0.213, 0.741, 0.512]
# =========================After updates========================
# Current errors are : [0.9410000000000001, 0.318, 0.562, 1.05, 0.791, 0.263, 0.5930000000000001]
#
# Episode 55
# Current errors are : [0.9410000000000001, 0.318, 0.562, 1.05, 0.791, 1.05, 0.5930000000000001]
# Sampled transitions [6, 0, 0] with probs [0.11178134 0.17737983 0.17737983]
# Generated TD-error : [0.745, 0.371, 0.174]
# =========================After updates========================
# Current errors are : [0.22399999999999998, 0.318, 0.562, 1.05, 0.791, 1.05, 0.795]
#
# Episode 56
# Current errors are : [0.22399999999999998, 0.318, 0.562, 1.05, 0.791, 1.05, 1.05]
# Sampled transitions [4, 5, 5] with probs [0.1567889  0.20812686 0.20812686]
# Generated TD-error : [0.045, 0.816, 0.177]
# =========================After updates========================
# Current errors are : [0.22399999999999998, 0.318, 0.562, 1.05, 0.09499999999999997, 0.22699999999999998, 1.05]
#
# Episode 57
# Current errors are : [1.05, 0.318, 0.562, 1.05, 0.09499999999999997, 0.22699999999999998, 1.05]
# Sampled transitions [6, 0, 6] with probs [0.24126838 0.24126838 0.24126838]
# Generated TD-error : [0.227, 0.452, 0.153]
# =========================After updates========================
# Current errors are : [0.502, 0.318, 0.562, 1.05, 0.09499999999999997, 0.22699999999999998, 0.203]
#
# Episode 58
# Current errors are : [0.502, 1.05, 0.562, 1.05, 0.09499999999999997, 0.22699999999999998, 0.203]
# Sampled transitions [0, 1, 2] with probs [0.13608024 0.28462997 0.15234481]
# Generated TD-error : [0.334, 0.101, 0.241]
# =========================After updates========================
# Current errors are : [0.384, 0.15100000000000002, 0.291, 1.05, 0.09499999999999997, 0.22699999999999998, 0.203]
#
# Episode 59
# Current errors are : [0.384, 0.15100000000000002, 1.05, 1.05, 0.09499999999999997, 0.22699999999999998, 0.203]
# Sampled transitions [3, 0, 2] with probs [0.3322785  0.12151898 0.3322785 ]
# Generated TD-error : [0.175, 0.061, 0.813]
# =========================After updates========================
# Current errors are : [0.11099999999999999, 0.15100000000000002, 0.863, 0.22499999999999998, 0.09499999999999997, 0.22699999999999998, 0.203]
#
# Episode 60
# Current errors are : [0.11099999999999999, 0.15100000000000002, 0.863, 1.05, 0.09499999999999997, 0.22699999999999998, 0.203]
# Sampled transitions [3, 3, 2] with probs [0.3888889  0.3888889  0.31962964]
# Generated TD-error : [0.657, 0.968, 0.535]
# =========================After updates========================
# Current errors are : [0.11099999999999999, 0.15100000000000002, 0.5850000000000001, 1.018, 0.09499999999999997, 0.22699999999999998, 0.203]
#
# Episode 61
# Current errors are : [0.11099999999999999, 0.15100000000000002, 0.5850000000000001, 1.018, 1.05, 0.22699999999999998, 0.203]
# Sampled transitions [4, 3, 3] with probs [0.31390134 0.30433482 0.30433482]
# Generated TD-error : [0.31, 0.199, 0.164]
# =========================After updates========================
# Current errors are : [0.11099999999999999, 0.15100000000000002, 0.5850000000000001, 0.21400000000000002, 0.36, 0.22699999999999998, 0.203]
#
# Episode 62
# Current errors are : [0.11099999999999999, 0.15100000000000002, 0.5850000000000001, 0.21400000000000002, 0.36, 1.05, 0.203]
# Sampled transitions [2, 2, 2] with probs [0.21877338 0.21877338 0.21877338]
# Generated TD-error : [0.157, 0.221, 0.131]
# =========================After updates========================
# Current errors are : [0.11099999999999999, 0.15100000000000002, 0.181, 0.21400000000000002, 0.36, 1.05, 0.203]
#
# Episode 63
# Current errors are : [0.11099999999999999, 0.15100000000000002, 0.181, 0.21400000000000002, 0.36, 1.05, 1.05]
# Sampled transitions [6, 5, 4] with probs [0.33686236 0.33686236 0.11549567]
# Generated TD-error : [0.067, 0.765, 0.691]
# =========================After updates========================
# Current errors are : [0.11099999999999999, 0.15100000000000002, 0.181, 0.21400000000000002, 0.741, 0.8150000000000001, 0.11699999999999999]
#
# Episode 64
# Current errors are : [1.05, 0.15100000000000002, 0.181, 0.21400000000000002, 0.741, 0.8150000000000001, 0.11699999999999999]
# Sampled transitions [0, 5, 5] with probs [0.32119915 0.24931172 0.24931172]
# Generated TD-error : [0.845, 0.038, 0.728]
# =========================After updates========================
# Current errors are : [0.895, 0.15100000000000002, 0.181, 0.21400000000000002, 0.741, 0.778, 0.11699999999999999]
#
# Episode 65
# Current errors are : [0.895, 1.05, 0.181, 0.21400000000000002, 0.741, 0.778, 0.11699999999999999]
# Sampled transitions [0, 4, 1] with probs [0.2251006  0.18636821 0.26408452]
# Generated TD-error : [0.83, 0.007, 0.554]
# =========================After updates========================
# Current errors are : [0.88, 0.6040000000000001, 0.181, 0.21400000000000002, 0.05700000000000005, 0.778, 0.11699999999999999]
#
# Episode 66
# Current errors are : [0.88, 0.6040000000000001, 1.05, 0.21400000000000002, 0.05700000000000005, 0.778, 0.11699999999999999]
# Sampled transitions [2, 2, 5] with probs [0.2837838  0.2837838  0.21027027]
# Generated TD-error : [0.6, 0.568, 0.713]
# =========================After updates========================
# Current errors are : [0.88, 0.6040000000000001, 0.618, 0.21400000000000002, 0.05700000000000005, 0.763, 0.11699999999999999]
#
# Episode 67
# Current errors are : [0.88, 0.6040000000000001, 0.618, 1.05, 0.05700000000000005, 0.763, 0.11699999999999999]
# Sampled transitions [1, 1, 1] with probs [0.14771338 0.14771338 0.14771338]
# Generated TD-error : [0.231, 0.513, 0.313]
# =========================After updates========================
# Current errors are : [0.88, 0.363, 0.618, 1.05, 0.05700000000000005, 0.763, 0.11699999999999999]
#
# Episode 68
# Current errors are : [0.88, 0.363, 0.618, 1.05, 1.05, 0.763, 0.11699999999999999]
# Sampled transitions [4, 3, 3] with probs [0.21689734 0.21689734 0.21689734]
# Generated TD-error : [0.543, 0.766, 0.541]
# =========================After updates========================
# Current errors are : [0.88, 0.363, 0.618, 0.5910000000000001, 0.5930000000000001, 0.763, 0.11699999999999999]
#
# Episode 69
# Current errors are : [0.88, 0.363, 0.618, 0.5910000000000001, 0.5930000000000001, 1.05, 0.11699999999999999]
# Sampled transitions [0, 0, 2] with probs [0.20892687 0.20892687 0.14672364]
# Generated TD-error : [0.293, 0.696, 0.637]
# =========================After updates========================
# Current errors are : [0.746, 0.363, 0.687, 0.5910000000000001, 0.5930000000000001, 1.05, 0.11699999999999999]
#
# Episode 70
# Current errors are : [0.746, 0.363, 0.687, 0.5910000000000001, 0.5930000000000001, 1.05, 1.05]
# Sampled transitions [6, 3, 4] with probs [0.20669292 0.11633858 0.11673228]
# Generated TD-error : [0.534, 0.09, 0.186]
# =========================After updates========================
# Current errors are : [0.746, 0.363, 0.687, 0.14, 0.236, 1.05, 0.5840000000000001]
#
# Episode 71
# Current errors are : [1.05, 0.363, 0.687, 0.14, 0.236, 1.05, 0.5840000000000001]
# Sampled transitions [5, 2, 5] with probs [0.25547445 0.16715328 0.25547445]
# Generated TD-error : [0.752, 0.79, 0.538]
# =========================After updates========================
# Current errors are : [1.05, 0.363, 0.8400000000000001, 0.14, 0.236, 0.5880000000000001, 0.5840000000000001]
#
# Episode 72
# Current errors are : [1.05, 1.05, 0.8400000000000001, 0.14, 0.236, 0.5880000000000001, 0.5840000000000001]
# Sampled transitions [6, 2, 2] with probs [0.13012478 0.18716578 0.18716578]
# Generated TD-error : [0.17, 0.91, 0.475]
# =========================After updates========================
# Current errors are : [1.05, 1.05, 0.525, 0.14, 0.236, 0.5880000000000001, 0.22000000000000003]
#
# Episode 73
# Current errors are : [1.05, 1.05, 1.05, 0.14, 0.236, 0.5880000000000001, 0.22000000000000003]
# Sampled transitions [2, 6, 1] with probs [0.24227042 0.05076142 0.24227042]
# Generated TD-error : [0.627, 0.274, 0.322]
# =========================After updates========================
# Current errors are : [1.05, 0.372, 0.677, 0.14, 0.236, 0.5880000000000001, 0.324]
#
# Episode 74
# Current errors are : [1.05, 0.372, 0.677, 1.05, 0.236, 0.5880000000000001, 0.324]
# Sampled transitions [3, 0, 0] with probs [0.24435653 0.24435653 0.24435653]
# Generated TD-error : [0.171, 0.432, 0.006]
# =========================After updates========================
# Current errors are : [0.055999999999999994, 0.372, 0.677, 0.22100000000000009, 0.236, 0.5880000000000001, 0.324]
#
# Episode 75
# Current errors are : [0.055999999999999994, 0.372, 0.677, 0.22100000000000009, 1.05, 0.5880000000000001, 0.324]
# Sampled transitions [4, 5, 4] with probs [0.31934306 0.17883211 0.31934306]
# Generated TD-error : [0.11, 0.569, 0.831]
# =========================After updates========================
# Current errors are : [0.055999999999999994, 0.372, 0.677, 0.22100000000000009, 0.881, 0.619, 0.324]
#
# Episode 76
# Current errors are : [0.055999999999999994, 0.372, 0.677, 0.22100000000000009, 0.881, 1.05, 0.324]
# Sampled transitions [6, 5, 5] with probs [0.09047752 0.29321417 0.29321417]
# Generated TD-error : [0.847, 0.434, 0.859]
# =========================After updates========================
# Current errors are : [0.055999999999999994, 0.372, 0.677, 0.22100000000000009, 0.881, 0.909, 0.897]
#
# Episode 77
# Current errors are : [0.055999999999999994, 0.372, 0.677, 0.22100000000000009, 0.881, 0.909, 1.05]
# Sampled transitions [5, 5, 6] with probs [0.21819492 0.21819492 0.25204033]
# Generated TD-error : [0.46, 0.094, 0.417]
# =========================After updates========================
# Current errors are : [0.055999999999999994, 0.372, 0.677, 0.22100000000000009, 0.881, 0.14400000000000002, 0.46699999999999997]
#
# Episode 78
# Current errors are : [1.05, 0.372, 0.677, 0.22100000000000009, 0.881, 0.14400000000000002, 0.46699999999999997]
# Sampled transitions [4, 2, 2] with probs [0.23111227 0.17759706 0.17759706]
# Generated TD-error : [0.199, 0.884, 0.062]
# =========================After updates========================
# Current errors are : [1.05, 0.372, 0.11199999999999999, 0.22100000000000009, 0.249, 0.14400000000000002, 0.46699999999999997]
#
# Episode 79
# Current errors are : [1.05, 1.05, 0.11199999999999999, 0.22100000000000009, 0.249, 0.14400000000000002, 0.46699999999999997]
# Sampled transitions [1, 0, 1] with probs [0.31885818 0.31885818 0.31885818]
# Generated TD-error : [0.688, 0.063, 0.899]
# =========================After updates========================
# Current errors are : [0.11299999999999999, 0.9490000000000001, 0.11199999999999999, 0.22100000000000009, 0.249, 0.14400000000000002, 0.46699999999999997]
#
# Episode 80
# Current errors are : [0.11299999999999999, 0.9490000000000001, 1.05, 0.22100000000000009, 0.249, 0.14400000000000002, 0.46699999999999997]
# Sampled transitions [2, 2, 2] with probs [0.32884434 0.32884434 0.32884434]
# Generated TD-error : [0.699, 0.584, 0.504]
# =========================After updates========================
# Current errors are : [0.11299999999999999, 0.9490000000000001, 0.554, 0.22100000000000009, 0.249, 0.14400000000000002, 0.46699999999999997]
#
# Episode 81
# Current errors are : [0.11299999999999999, 0.9490000000000001, 0.554, 1.05, 0.249, 0.14400000000000002, 0.46699999999999997]
# Sampled transitions [3, 6, 1] with probs [0.29778787 0.1324447  0.2691435 ]
# Generated TD-error : [0.143, 0.321, 0.388]
# =========================After updates========================
# Current errors are : [0.11299999999999999, 0.43799999999999994, 0.554, 0.19300000000000006, 0.249, 0.14400000000000002, 0.371]
#
# Episode 82
# Current errors are : [0.11299999999999999, 0.43799999999999994, 0.554, 0.19300000000000006, 1.05, 0.14400000000000002, 0.371]
# Sampled transitions [4, 0, 6] with probs [0.36674815 0.03946909 0.12958436]
# Generated TD-error : [0.677, 0.253, 0.349]
# =========================After updates========================
# Current errors are : [0.303, 0.43799999999999994, 0.554, 0.19300000000000006, 0.7270000000000001, 0.14400000000000002, 0.39899999999999997]
#
# Episode 83
# Current errors are : [0.303, 0.43799999999999994, 0.554, 0.19300000000000006, 0.7270000000000001, 1.05, 0.39899999999999997]
# Sampled transitions [0, 2, 4] with probs [0.0826965  0.15120088 0.19841704]
# Generated TD-error : [0.995, 0.469, 0.916]
# =========================After updates========================
# Current errors are : [1.045, 0.43799999999999994, 0.519, 0.19300000000000006, 0.9660000000000001, 1.05, 0.39899999999999997]
#
# Episode 84
# Current errors are : [1.045, 0.43799999999999994, 0.519, 0.19300000000000006, 0.9660000000000001, 1.05, 1.05]
# Sampled transitions [0, 4, 6] with probs [0.19863144 0.18361528 0.19958183]
# Generated TD-error : [0.354, 0.834, 0.152]
# =========================After updates========================
# Current errors are : [0.4039999999999999, 0.43799999999999994, 0.519, 0.19300000000000006, 0.884, 1.05, 0.20199999999999996]
#
# Episode 85
# Current errors are : [1.05, 0.43799999999999994, 0.519, 0.19300000000000006, 0.884, 1.05, 0.20199999999999996]
# Sampled transitions [5, 5, 0] with probs [0.24215867 0.24215867 0.24215867]
# Generated TD-error : [0.257, 0.307, 0.79]
# =========================After updates========================
# Current errors are : [0.8400000000000001, 0.43799999999999994, 0.519, 0.19300000000000006, 0.884, 0.357, 0.20199999999999996]
#
# Episode 86
# Current errors are : [0.8400000000000001, 1.05, 0.519, 0.19300000000000006, 0.884, 0.357, 0.20199999999999996]
# Sampled transitions [4, 4, 0] with probs [0.21854141 0.21854141 0.20766379]
# Generated TD-error : [0.239, 0.152, 0.531]
# =========================After updates========================
# Current errors are : [0.5810000000000001, 1.05, 0.519, 0.19300000000000006, 0.202, 0.357, 0.20199999999999996]
#
# Episode 87
# Current errors are : [0.5810000000000001, 1.05, 1.05, 0.19300000000000006, 0.202, 0.357, 0.20199999999999996]
# Sampled transitions [5, 5, 4] with probs [0.09821183 0.09821183 0.05557084]
# Generated TD-error : [0.058, 0.075, 0.684]
# =========================After updates========================
# Current errors are : [0.5810000000000001, 1.05, 1.05, 0.19300000000000006, 0.734, 0.125, 0.20199999999999996]
#
# Episode 88
# Current errors are : [0.5810000000000001, 1.05, 1.05, 1.05, 0.734, 0.125, 0.20199999999999996]
# Sampled transitions [2, 1, 4] with probs [0.2191152  0.2191152  0.15317196]
# Generated TD-error : [0.992, 0.905, 0.276]
# =========================After updates========================
# Current errors are : [0.5810000000000001, 0.9550000000000001, 1.042, 1.05, 0.326, 0.125, 0.20199999999999996]
#
# Episode 89
# Current errors are : [0.5810000000000001, 0.9550000000000001, 1.042, 1.05, 1.05, 0.125, 0.20199999999999996]
# Sampled transitions [3, 3, 2] with probs [0.20979021 0.20979021 0.20819181]
# Generated TD-error : [0.145, 0.522, 0.913]
# =========================After updates========================
# Current errors are : [0.5810000000000001, 0.9550000000000001, 0.9630000000000001, 0.5720000000000001, 1.05, 0.125, 0.20199999999999996]
#
# Episode 90
# Current errors are : [0.5810000000000001, 0.9550000000000001, 0.9630000000000001, 0.5720000000000001, 1.05, 1.05, 0.20199999999999996]
# Sampled transitions [5, 4, 2] with probs [0.19542155 0.19542155 0.17922948]
# Generated TD-error : [0.66, 0.362, 0.223]
# =========================After updates========================
# Current errors are : [0.5810000000000001, 0.9550000000000001, 0.273, 0.5720000000000001, 0.4119999999999999, 0.7100000000000001, 0.20199999999999996]
#
# Episode 91
# Current errors are : [0.5810000000000001, 0.9550000000000001, 0.273, 0.5720000000000001, 0.4119999999999999, 0.7100000000000001, 1.05]
# Sampled transitions [5, 5, 3] with probs [0.15594114 0.15594114 0.12563145]
# Generated TD-error : [0.018, 0.948, 0.049]
# =========================After updates========================
# Current errors are : [0.5810000000000001, 0.9550000000000001, 0.273, 0.09899999999999998, 0.4119999999999999, 0.998, 1.05]
#
# Episode 92
# Current errors are : [1.05, 0.9550000000000001, 0.273, 0.09899999999999998, 0.4119999999999999, 0.998, 1.05]
# Sampled transitions [6, 4, 2] with probs [0.2170767  0.08517677 0.05643994]
# Generated TD-error : [0.768, 0.051, 0.587]
# =========================After updates========================
# Current errors are : [1.05, 0.9550000000000001, 0.637, 0.09899999999999998, 0.10099999999999998, 0.998, 0.8180000000000001]
#
# Episode 93
# Current errors are : [1.05, 1.05, 0.637, 0.09899999999999998, 0.10099999999999998, 0.998, 0.8180000000000001]
# Sampled transitions [2, 5, 1] with probs [0.13402061 0.20997265 0.22091311]
# Generated TD-error : [0.924, 0.988, 0.575]
# =========================After updates========================
# Current errors are : [1.05, 0.625, 0.9740000000000001, 0.09899999999999998, 0.10099999999999998, 1.038, 0.8180000000000001]
#
# Episode 94
# Current errors are : [1.05, 0.625, 1.05, 0.09899999999999998, 0.10099999999999998, 1.038, 0.8180000000000001]
# Sampled transitions [5, 0, 2] with probs [0.2171094  0.21961933 0.21961933]
# Generated TD-error : [0.648, 0.435, 0.338]
# =========================After updates========================
# Current errors are : [0.485, 0.625, 0.388, 0.09899999999999998, 0.10099999999999998, 0.6980000000000001, 0.8180000000000001]
#
# Episode 95
# Current errors are : [0.485, 0.625, 0.388, 1.05, 0.10099999999999998, 0.6980000000000001, 0.8180000000000001]
# Sampled transitions [3, 5, 5] with probs [0.25210086 0.16758704 0.16758704]
# Generated TD-error : [0.713, 0.257, 0.46]
# =========================After updates========================
# Current errors are : [0.485, 0.625, 0.388, 0.763, 0.10099999999999998, 0.51, 0.8180000000000001]
#
# Episode 96
# Current errors are : [0.485, 0.625, 0.388, 0.763, 1.05, 0.51, 0.8180000000000001]
# Sampled transitions [4, 2, 0] with probs [0.22634189 0.08363871 0.10454839]
# Generated TD-error : [0.999, 0.83, 0.736]
# =========================After updates========================
# Current errors are : [0.786, 0.625, 0.88, 0.763, 1.049, 0.51, 0.8180000000000001]
#
# Episode 97
# Current errors are : [0.786, 0.625, 0.88, 0.763, 1.049, 1.05, 0.8180000000000001]
# Sampled transitions [5, 2, 4] with probs [0.17584994 0.147379   0.17568247]
# Generated TD-error : [0.109, 0.624, 0.746]
# =========================After updates========================
# Current errors are : [0.786, 0.625, 0.674, 0.763, 0.796, 0.15900000000000003, 0.8180000000000001]
#
# Episode 98
# Current errors are : [0.786, 0.625, 0.674, 0.763, 0.796, 0.15900000000000003, 1.05]
# Sampled transitions [2, 4, 4] with probs [0.13888316 0.16402225 0.16402225]
# Generated TD-error : [0.388, 0.866, 0.399]
# =========================After updates========================
# Current errors are : [0.786, 0.625, 0.438, 0.763, 0.449, 0.15900000000000003, 1.05]
#
# Episode 99
# Current errors are : [1.05, 0.625, 0.438, 0.763, 0.449, 0.15900000000000003, 1.05]
# Sampled transitions [1, 4, 2] with probs [0.13784738 0.09902956 0.09660344]
# Generated TD-error : [0.165, 0.462, 0.221]
# =========================After updates========================
# Current errors are : [1.05, 0.21500000000000002, 0.271, 0.763, 0.512, 0.15900000000000003, 1.05]
#
# Episode 100
# Current errors are : [1.05, 1.05, 0.271, 0.763, 0.512, 0.15900000000000003, 1.05]
# Sampled transitions [1, 0, 4] with probs [0.21627188 0.21627188 0.10545829]
# Generated TD-error : [0.42, 0.205, 0.414]
# =========================After updates========================
# Current errors are : [0.255, 0.47, 0.271, 0.763, 0.46399999999999997, 0.15900000000000003, 1.05]

# %%
capacity = 7
batch_size = 3
N = 100

test = Rank_Replay_Buffer(capacity=capacity, batch_size=batch_size)
for i in range(N):
    test.remember(*get_transition(i % 10))
    print('Episode {}'.format(i+1))
    print('Current relations (memory_to_rank) are : {}'.format(test.memory_to_rank))
    print('Current errors (td_error, index) are : {}'.format(test.errors))
    print('Current segment weights are : {}'.format([test.total_weights * (i / batch_size) for i in range(1, batch_size+1)]))
    print('Current cumulated sums are : {}'.format(test.cumulated_weights))
    print('Current segment is : {}'.format(test.segments))
    if len(test) >= batch_size:
        temp_index, temp_states, temp_actions, temp_rewards, temp_next_states, temp_dones, temp_probs = test.sample(batch_size)
        temp_probs = temp_probs.numpy().reshape(-1)
        delta = [np.round(random.random(), 3) for _ in range(batch_size)]
        print('Sampled transitions {} with probs {}'.format(temp_index, temp_probs))
        print('Generated TD-error : {}'.format(delta))
        for ind, error in zip(temp_index, delta):
            test.insert(error, ind)
        print('=========================After updates========================')
        print('Current relations (memory_to_rank) are : {}'.format(test.memory_to_rank))
        print('Current errors (td_error, index) are : {}'.format(test.errors))
    print()
# Out:
# Episode 1
# Current relations (memory_to_rank) are : [0, None, None, None, None, None, None]
# Current errors (td_error, index) are : [(0, 0)]
# Current segment weights are : [0.3333333333333333, 0.6666666666666666, 1.0]
# Current cumulated sums are : [1.0]
# Current segment is : [-1, None, None, None]
#
# Episode 2
# Current relations (memory_to_rank) are : [0, 1, None, None, None, None, None]
# Current errors (td_error, index) are : [(0, 0), (0, 1)]
# Current segment weights are : [0.5690355937288492, 1.1380711874576983, 1.7071067811865475]
# Current cumulated sums are : [1.0, 1.7071067811865475]
# Current segment is : [-1, None, None, None]
#
# Episode 3
# Current relations (memory_to_rank) are : [0, 1, 2, None, None, None, None]
# Current errors (td_error, index) are : [(0, 0), (0, 1), (0, 2)]
# Current segment weights are : [0.7614856834587244, 1.5229713669174487, 2.284457050376173]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173]
# Current segment is : [-1, 0, 1, 2]
# Sampled transitions [0, 1, 2] with probs [0.43774077 0.30952948 0.25272974]
# Generated TD-error : [0.164, 0.442, 0.147]
# =========================After updates========================
# Current relations (memory_to_rank) are : [1, 0, 2, None, None, None, None]
# Current errors (td_error, index) are : [(-0.442, 1), (-0.164, 0), (-0.147, 2)]
#
# Episode 4
# Current relations (memory_to_rank) are : [2, 0, 3, 1, None, None, None]
# Current errors (td_error, index) are : [(-0.442, 1), (-0.442, 3), (-0.164, 0), (-0.147, 2)]
# Current segment weights are : [0.928152350125391, 1.856304700250782, 2.784457050376173]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173]
# Current segment is : [-1, 0, 2, 3]
# Sampled transitions [1, 0, 2] with probs [0.35913643 0.20734753 0.17956822]
# Generated TD-error : [0.698, 0.66, 0.661]
# =========================After updates========================
# Current relations (memory_to_rank) are : [2, 0, 1, 3, None, None, None]
# Current errors (td_error, index) are : [(-0.698, 1), (-0.661, 2), (-0.66, 0), (-0.442, 3)]
#
# Episode 5
# Current relations (memory_to_rank) are : [3, 0, 2, 4, 1, None, None]
# Current errors (td_error, index) are : [(-0.698, 1), (-0.698, 4), (-0.661, 2), (-0.66, 0), (-0.442, 3)]
# Current segment weights are : [1.077223548625377, 2.154447097250754, 3.231670645876131]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131]
# Current segment is : [-1, 1, 2, 4]
# Sampled transitions [1, 2, 3] with probs [0.30943748 0.1786538  0.13838464]
# Generated TD-error : [0.275, 0.688, 0.639]
# =========================After updates========================
# Current relations (memory_to_rank) are : [2, 4, 1, 3, 0, None, None]
# Current errors (td_error, index) are : [(-0.698, 4), (-0.688, 2), (-0.66, 0), (-0.639, 3), (-0.275, 1)]
#
# Episode 6
# Current relations (memory_to_rank) are : [3, 5, 2, 4, 0, 1, None]
# Current errors (td_error, index) are : [(-0.698, 4), (-0.698, 5), (-0.688, 2), (-0.66, 0), (-0.639, 3), (-0.275, 1)]
# Current segment weights are : [1.2133063121133314, 2.426612624226663, 3.639918936339994]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994]
# Current segment is : [-1, 1, 3, 5]
# Sampled transitions [5, 2, 3] with probs [0.19426443 0.15861624 0.12286361]
# Generated TD-error : [0.511, 0.587, 0.044]
# =========================After updates========================
# Current relations (memory_to_rank) are : [1, 4, 2, 5, 0, 3, None]
# Current errors (td_error, index) are : [(-0.698, 4), (-0.66, 0), (-0.587, 2), (-0.511, 5), (-0.275, 1), (-0.044, 3)]
#
# Episode 7
# Current relations (memory_to_rank) are : [2, 5, 3, 6, 0, 4, 1]
# Current errors (td_error, index) are : [(-0.698, 4), (-0.698, 6), (-0.66, 0), (-0.587, 2), (-0.511, 5), (-0.275, 1), (-0.044, 3)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [6, 0, 5] with probs [0.17598987 0.14369513 0.11130577]
# Generated TD-error : [0.164, 0.636, 0.086]
# =========================After updates========================
# Current relations (memory_to_rank) are : [1, 3, 2, 6, 0, 5, 4]
# Current errors (td_error, index) are : [(-0.698, 4), (-0.636, 0), (-0.587, 2), (-0.275, 1), (-0.164, 6), (-0.086, 5), (-0.044, 3)]
#
# Episode 8
# Current relations (memory_to_rank) are : [0, 3, 2, 6, 1, 5, 4]
# Current errors (td_error, index) are : [(-0.698, 0), (-0.698, 4), (-0.587, 2), (-0.275, 1), (-0.164, 6), (-0.086, 5), (-0.044, 3)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [0, 1, 5] with probs [0.24888726 0.12444363 0.1016078 ]
# Generated TD-error : [0.347, 0.16, 0.331]
# =========================After updates========================
# Current relations (memory_to_rank) are : [2, 5, 1, 6, 0, 3, 4]
# Current errors (td_error, index) are : [(-0.698, 4), (-0.587, 2), (-0.347, 0), (-0.331, 5), (-0.164, 6), (-0.16, 1), (-0.044, 3)]
#
# Episode 9
# Current relations (memory_to_rank) are : [3, 0, 2, 6, 1, 4, 5]
# Current errors (td_error, index) are : [(-0.698, 1), (-0.698, 4), (-0.587, 2), (-0.347, 0), (-0.331, 5), (-0.164, 6), (-0.044, 3)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [1, 0, 3] with probs [0.24888726 0.12444363 0.09407055]
# Generated TD-error : [0.475, 0.704, 0.479]
# =========================After updates========================
# Current relations (memory_to_rank) are : [0, 4, 2, 3, 1, 5, 6]
# Current errors (td_error, index) are : [(-0.704, 0), (-0.698, 4), (-0.587, 2), (-0.479, 3), (-0.475, 1), (-0.331, 5), (-0.164, 6)]
#
# Episode 10
# Current relations (memory_to_rank) are : [0, 4, 1, 3, 2, 5, 6]
# Current errors (td_error, index) are : [(-0.704, 0), (-0.704, 2), (-0.698, 4), (-0.479, 3), (-0.475, 1), (-0.331, 5), (-0.164, 6)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [2, 4, 5] with probs [0.17598987 0.14369513 0.1016078 ]
# Generated TD-error : [0.389, 0.558, 0.928]
# =========================After updates========================
# Current relations (memory_to_rank) are : [1, 4, 5, 3, 2, 0, 6]
# Current errors (td_error, index) are : [(-0.928, 5), (-0.704, 0), (-0.558, 4), (-0.479, 3), (-0.475, 1), (-0.389, 2), (-0.164, 6)]
#
# Episode 11
# Current relations (memory_to_rank) are : [2, 4, 5, 0, 3, 1, 6]
# Current errors (td_error, index) are : [(-0.928, 3), (-0.928, 5), (-0.704, 0), (-0.558, 4), (-0.475, 1), (-0.389, 2), (-0.164, 6)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [3, 4, 1] with probs [0.24888726 0.12444363 0.11130577]
# Generated TD-error : [0.148, 0.297, 0.209]
# =========================After updates========================
# Current relations (memory_to_rank) are : [1, 4, 2, 6, 3, 0, 5]
# Current errors (td_error, index) are : [(-0.928, 5), (-0.704, 0), (-0.389, 2), (-0.297, 4), (-0.209, 1), (-0.164, 6), (-0.148, 3)]
#
# Episode 12
# Current relations (memory_to_rank) are : [2, 4, 3, 6, 0, 1, 5]
# Current errors (td_error, index) are : [(-0.928, 4), (-0.928, 5), (-0.704, 0), (-0.389, 2), (-0.209, 1), (-0.164, 6), (-0.148, 3)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [4, 0, 1] with probs [0.24888726 0.14369513 0.11130577]
# Generated TD-error : [0.592, 0.507, 0.917]
# =========================After updates========================
# Current relations (memory_to_rank) are : [3, 1, 4, 6, 2, 0, 5]
# Current errors (td_error, index) are : [(-0.928, 5), (-0.917, 1), (-0.592, 4), (-0.507, 0), (-0.389, 2), (-0.164, 6), (-0.148, 3)]
#
# Episode 13
# Current relations (memory_to_rank) are : [3, 0, 4, 6, 2, 1, 5]
# Current errors (td_error, index) are : [(-0.917, 1), (-0.917, 5), (-0.592, 4), (-0.507, 0), (-0.389, 2), (-0.164, 6), (-0.148, 3)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [5, 0, 3] with probs [0.17598987 0.12444363 0.09407055]
# Generated TD-error : [0.505, 0.246, 0.654]
# =========================After updates========================
# Current relations (memory_to_rank) are : [5, 0, 4, 1, 2, 3, 6]
# Current errors (td_error, index) are : [(-0.917, 1), (-0.654, 3), (-0.592, 4), (-0.505, 5), (-0.389, 2), (-0.246, 0), (-0.164, 6)]
#
# Episode 14
# Current relations (memory_to_rank) are : [6, 0, 5, 2, 3, 4, 1]
# Current errors (td_error, index) are : [(-0.917, 1), (-0.917, 6), (-0.654, 3), (-0.592, 4), (-0.505, 5), (-0.389, 2), (-0.246, 0)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [1, 3, 2] with probs [0.24888726 0.14369513 0.1016078 ]
# Generated TD-error : [0.301, 0.642, 0.885]
# =========================After updates========================
# Current relations (memory_to_rank) are : [6, 5, 1, 2, 3, 4, 0]
# Current errors (td_error, index) are : [(-0.917, 6), (-0.885, 2), (-0.642, 3), (-0.592, 4), (-0.505, 5), (-0.301, 1), (-0.246, 0)]
#
# Episode 15
# Current relations (memory_to_rank) are : [0, 6, 2, 3, 4, 5, 1]
# Current errors (td_error, index) are : [(-0.917, 0), (-0.917, 6), (-0.885, 2), (-0.642, 3), (-0.592, 4), (-0.505, 5), (-0.301, 1)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [0, 3, 1] with probs [0.24888726 0.12444363 0.09407055]
# Generated TD-error : [0.462, 0.341, 0.575]
# =========================After updates========================
# Current relations (memory_to_rank) are : [5, 3, 1, 6, 2, 4, 0]
# Current errors (td_error, index) are : [(-0.917, 6), (-0.885, 2), (-0.592, 4), (-0.575, 1), (-0.505, 5), (-0.462, 0), (-0.341, 3)]
#
# Episode 16
# Current relations (memory_to_rank) are : [5, 0, 2, 6, 3, 4, 1]
# Current errors (td_error, index) are : [(-0.917, 1), (-0.917, 6), (-0.885, 2), (-0.592, 4), (-0.505, 5), (-0.462, 0), (-0.341, 3)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [6, 4, 5] with probs [0.17598987 0.12444363 0.11130577]
# Generated TD-error : [0.78, 0.201, 0.999]
# =========================After updates========================
# Current relations (memory_to_rank) are : [4, 1, 2, 5, 6, 0, 3]
# Current errors (td_error, index) are : [(-0.999, 5), (-0.917, 1), (-0.885, 2), (-0.78, 6), (-0.462, 0), (-0.341, 3), (-0.201, 4)]
#
# Episode 17
# Current relations (memory_to_rank) are : [4, 2, 0, 5, 6, 1, 3]
# Current errors (td_error, index) are : [(-0.999, 2), (-0.999, 5), (-0.917, 1), (-0.78, 6), (-0.462, 0), (-0.341, 3), (-0.201, 4)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [5, 6, 0] with probs [0.17598987 0.12444363 0.11130577]
# Generated TD-error : [0.946, 0.864, 0.887]
# =========================After updates========================
# Current relations (memory_to_rank) are : [3, 2, 0, 5, 6, 1, 4]
# Current errors (td_error, index) are : [(-0.999, 2), (-0.946, 5), (-0.917, 1), (-0.887, 0), (-0.864, 6), (-0.341, 3), (-0.201, 4)]
#
# Episode 18
# Current relations (memory_to_rank) are : [4, 3, 0, 1, 6, 2, 5]
# Current errors (td_error, index) are : [(-0.999, 2), (-0.999, 3), (-0.946, 5), (-0.917, 1), (-0.887, 0), (-0.864, 6), (-0.201, 4)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [3, 1, 4] with probs [0.17598987 0.12444363 0.09407055]
# Generated TD-error : [0.551, 0.291, 0.125]
# =========================After updates========================
# Current relations (memory_to_rank) are : [2, 5, 0, 4, 6, 1, 3]
# Current errors (td_error, index) are : [(-0.999, 2), (-0.946, 5), (-0.887, 0), (-0.864, 6), (-0.551, 3), (-0.291, 1), (-0.125, 4)]
#
# Episode 19
# Current relations (memory_to_rank) are : [3, 6, 0, 5, 1, 2, 4]
# Current errors (td_error, index) are : [(-0.999, 2), (-0.999, 4), (-0.946, 5), (-0.887, 0), (-0.864, 6), (-0.551, 3), (-0.291, 1)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [4, 5, 6] with probs [0.17598987 0.14369513 0.11130577]
# Generated TD-error : [0.141, 0.369, 0.718]
# =========================After updates========================
# Current relations (memory_to_rank) are : [1, 5, 0, 3, 6, 4, 2]
# Current errors (td_error, index) are : [(-0.999, 2), (-0.887, 0), (-0.718, 6), (-0.551, 3), (-0.369, 5), (-0.291, 1), (-0.141, 4)]
#
# Episode 20
# Current relations (memory_to_rank) are : [2, 5, 0, 4, 6, 1, 3]
# Current errors (td_error, index) are : [(-0.999, 2), (-0.999, 5), (-0.887, 0), (-0.718, 6), (-0.551, 3), (-0.291, 1), (-0.141, 4)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [2, 0, 4] with probs [0.24888726 0.14369513 0.09407055]
# Generated TD-error : [0.674, 0.279, 0.456]
# =========================After updates========================
# Current relations (memory_to_rank) are : [6, 5, 2, 3, 4, 0, 1]
# Current errors (td_error, index) are : [(-0.999, 5), (-0.718, 6), (-0.674, 2), (-0.551, 3), (-0.456, 4), (-0.291, 1), (-0.279, 0)]
#
# Episode 21
# Current relations (memory_to_rank) are : [6, 5, 2, 3, 4, 0, 1]
# Current errors (td_error, index) are : [(-0.999, 5), (-0.999, 6), (-0.674, 2), (-0.551, 3), (-0.456, 4), (-0.291, 1), (-0.279, 0)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [6, 3, 1] with probs [0.17598987 0.12444363 0.1016078 ]
# Generated TD-error : [0.67, 0.026, 0.48]
# =========================After updates========================
# Current relations (memory_to_rank) are : [5, 3, 1, 6, 4, 0, 2]
# Current errors (td_error, index) are : [(-0.999, 5), (-0.674, 2), (-0.67, 6), (-0.48, 1), (-0.456, 4), (-0.279, 0), (-0.026, 3)]
#
# Episode 22
# Current relations (memory_to_rank) are : [0, 4, 2, 6, 5, 1, 3]
# Current errors (td_error, index) are : [(-0.999, 0), (-0.999, 5), (-0.674, 2), (-0.67, 6), (-0.48, 1), (-0.456, 4), (-0.026, 3)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [5, 2, 3] with probs [0.17598987 0.14369513 0.09407055]
# Generated TD-error : [0.873, 0.564, 0.142]
# =========================After updates========================
# Current relations (memory_to_rank) are : [0, 4, 3, 6, 5, 1, 2]
# Current errors (td_error, index) are : [(-0.999, 0), (-0.873, 5), (-0.67, 6), (-0.564, 2), (-0.48, 1), (-0.456, 4), (-0.142, 3)]
#
# Episode 23
# Current relations (memory_to_rank) are : [0, 1, 4, 6, 5, 2, 3]
# Current errors (td_error, index) are : [(-0.999, 0), (-0.999, 1), (-0.873, 5), (-0.67, 6), (-0.564, 2), (-0.456, 4), (-0.142, 3)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [1, 5, 2] with probs [0.17598987 0.14369513 0.11130577]
# Generated TD-error : [0.928, 0.633, 0.507]
# =========================After updates========================
# Current relations (memory_to_rank) are : [0, 1, 4, 6, 5, 3, 2]
# Current errors (td_error, index) are : [(-0.999, 0), (-0.928, 1), (-0.67, 6), (-0.633, 5), (-0.507, 2), (-0.456, 4), (-0.142, 3)]
#
# Episode 24
# Current relations (memory_to_rank) are : [0, 2, 1, 6, 5, 4, 3]
# Current errors (td_error, index) are : [(-0.999, 0), (-0.999, 2), (-0.928, 1), (-0.67, 6), (-0.633, 5), (-0.456, 4), (-0.142, 3)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [2, 6, 5] with probs [0.17598987 0.12444363 0.11130577]
# Generated TD-error : [0.721, 0.609, 0.961]
# =========================After updates========================
# Current relations (memory_to_rank) are : [0, 2, 3, 6, 5, 1, 4]
# Current errors (td_error, index) are : [(-0.999, 0), (-0.961, 5), (-0.928, 1), (-0.721, 2), (-0.609, 6), (-0.456, 4), (-0.142, 3)]
#
# Episode 25
# Current relations (memory_to_rank) are : [0, 3, 4, 1, 6, 2, 5]
# Current errors (td_error, index) are : [(-0.999, 0), (-0.999, 3), (-0.961, 5), (-0.928, 1), (-0.721, 2), (-0.609, 6), (-0.456, 4)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [0, 1, 4] with probs [0.24888726 0.12444363 0.09407055]
# Generated TD-error : [0.569, 0.081, 0.223]
# =========================After updates========================
# Current relations (memory_to_rank) are : [4, 6, 2, 0, 5, 1, 3]
# Current errors (td_error, index) are : [(-0.999, 3), (-0.961, 5), (-0.721, 2), (-0.609, 6), (-0.569, 0), (-0.223, 4), (-0.081, 1)]
#
# Episode 26
# Current relations (memory_to_rank) are : [5, 6, 3, 0, 1, 2, 4]
# Current errors (td_error, index) are : [(-0.999, 3), (-0.999, 4), (-0.961, 5), (-0.721, 2), (-0.609, 6), (-0.569, 0), (-0.081, 1)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [3, 5, 1] with probs [0.24888726 0.14369513 0.09407055]
# Generated TD-error : [0.228, 0.146, 0.862]
# =========================After updates========================
# Current relations (memory_to_rank) are : [4, 1, 2, 5, 0, 6, 3]
# Current errors (td_error, index) are : [(-0.999, 4), (-0.862, 1), (-0.721, 2), (-0.609, 6), (-0.569, 0), (-0.228, 3), (-0.146, 5)]
#
# Episode 27
# Current relations (memory_to_rank) are : [5, 2, 3, 6, 0, 1, 4]
# Current errors (td_error, index) are : [(-0.999, 4), (-0.999, 5), (-0.862, 1), (-0.721, 2), (-0.609, 6), (-0.569, 0), (-0.228, 3)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [5, 2, 3] with probs [0.17598987 0.12444363 0.09407055]
# Generated TD-error : [0.364, 0.509, 0.263]
# =========================After updates========================
# Current relations (memory_to_rank) are : [3, 1, 4, 6, 0, 5, 2]
# Current errors (td_error, index) are : [(-0.999, 4), (-0.862, 1), (-0.609, 6), (-0.569, 0), (-0.509, 2), (-0.364, 5), (-0.263, 3)]
#
# Episode 28
# Current relations (memory_to_rank) are : [3, 2, 4, 6, 0, 5, 1]
# Current errors (td_error, index) are : [(-0.999, 4), (-0.999, 6), (-0.862, 1), (-0.569, 0), (-0.509, 2), (-0.364, 5), (-0.263, 3)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [4, 1, 3] with probs [0.24888726 0.14369513 0.09407055]
# Generated TD-error : [0.574, 0.101, 0.833]
# =========================After updates========================
# Current relations (memory_to_rank) are : [3, 6, 4, 1, 2, 5, 0]
# Current errors (td_error, index) are : [(-0.999, 6), (-0.833, 3), (-0.574, 4), (-0.569, 0), (-0.509, 2), (-0.364, 5), (-0.101, 1)]
#
# Episode 29
# Current relations (memory_to_rank) are : [0, 6, 4, 2, 3, 5, 1]
# Current errors (td_error, index) are : [(-0.999, 0), (-0.999, 6), (-0.833, 3), (-0.574, 4), (-0.509, 2), (-0.364, 5), (-0.101, 1)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [0, 3, 1] with probs [0.24888726 0.14369513 0.09407055]
# Generated TD-error : [0.193, 0.558, 0.935]
# =========================After updates========================
# Current relations (memory_to_rank) are : [6, 1, 4, 3, 2, 5, 0]
# Current errors (td_error, index) are : [(-0.999, 6), (-0.935, 1), (-0.574, 4), (-0.558, 3), (-0.509, 2), (-0.364, 5), (-0.193, 0)]
#
# Episode 30
# Current relations (memory_to_rank) are : [6, 0, 4, 3, 2, 5, 1]
# Current errors (td_error, index) are : [(-0.999, 1), (-0.999, 6), (-0.574, 4), (-0.558, 3), (-0.509, 2), (-0.364, 5), (-0.193, 0)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [1, 3, 5] with probs [0.24888726 0.12444363 0.1016078 ]
# Generated TD-error : [0.144, 0.678, 0.865]
# =========================After updates========================
# Current relations (memory_to_rank) are : [5, 6, 4, 2, 3, 1, 0]
# Current errors (td_error, index) are : [(-0.999, 6), (-0.865, 5), (-0.678, 3), (-0.574, 4), (-0.509, 2), (-0.193, 0), (-0.144, 1)]
#
# Episode 31
# Current relations (memory_to_rank) are : [5, 6, 0, 3, 4, 2, 1]
# Current errors (td_error, index) are : [(-0.999, 2), (-0.999, 6), (-0.865, 5), (-0.678, 3), (-0.574, 4), (-0.193, 0), (-0.144, 1)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [2, 5, 0] with probs [0.24888726 0.14369513 0.1016078 ]
# Generated TD-error : [0.898, 0.261, 0.27]
# =========================After updates========================
# Current relations (memory_to_rank) are : [4, 6, 1, 2, 3, 5, 0]
# Current errors (td_error, index) are : [(-0.999, 6), (-0.898, 2), (-0.678, 3), (-0.574, 4), (-0.27, 0), (-0.261, 5), (-0.144, 1)]
#
# Episode 32
# Current relations (memory_to_rank) are : [4, 6, 2, 0, 3, 5, 1]
# Current errors (td_error, index) are : [(-0.999, 3), (-0.999, 6), (-0.898, 2), (-0.574, 4), (-0.27, 0), (-0.261, 5), (-0.144, 1)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [3, 2, 1] with probs [0.24888726 0.14369513 0.09407055]
# Generated TD-error : [0.618, 0.361, 0.581]
# =========================After updates========================
# Current relations (memory_to_rank) are : [5, 2, 4, 1, 3, 6, 0]
# Current errors (td_error, index) are : [(-0.999, 6), (-0.618, 3), (-0.581, 1), (-0.574, 4), (-0.361, 2), (-0.27, 0), (-0.261, 5)]
#
# Episode 33
# Current relations (memory_to_rank) are : [5, 3, 4, 2, 0, 6, 1]
# Current errors (td_error, index) are : [(-0.999, 4), (-0.999, 6), (-0.618, 3), (-0.581, 1), (-0.361, 2), (-0.27, 0), (-0.261, 5)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [6, 1, 2] with probs [0.17598987 0.12444363 0.11130577]
# Generated TD-error : [0.636, 0.921, 0.786]
# =========================After updates========================
# Current relations (memory_to_rank) are : [5, 1, 2, 4, 0, 6, 3]
# Current errors (td_error, index) are : [(-0.999, 4), (-0.921, 1), (-0.786, 2), (-0.636, 6), (-0.618, 3), (-0.27, 0), (-0.261, 5)]
#
# Episode 34
# Current relations (memory_to_rank) are : [6, 2, 3, 5, 0, 1, 4]
# Current errors (td_error, index) are : [(-0.999, 4), (-0.999, 5), (-0.921, 1), (-0.786, 2), (-0.636, 6), (-0.618, 3), (-0.27, 0)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [4, 1, 3] with probs [0.24888726 0.14369513 0.1016078 ]
# Generated TD-error : [0.639, 0.084, 0.362]
# =========================After updates========================
# Current relations (memory_to_rank) are : [5, 6, 1, 4, 2, 0, 3]
# Current errors (td_error, index) are : [(-0.999, 5), (-0.786, 2), (-0.639, 4), (-0.636, 6), (-0.362, 3), (-0.27, 0), (-0.084, 1)]
#
# Episode 35
# Current relations (memory_to_rank) are : [5, 6, 2, 4, 3, 0, 1]
# Current errors (td_error, index) are : [(-0.999, 5), (-0.999, 6), (-0.786, 2), (-0.639, 4), (-0.362, 3), (-0.27, 0), (-0.084, 1)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [5, 2, 3] with probs [0.24888726 0.14369513 0.11130577]
# Generated TD-error : [0.523, 0.986, 0.03]
# =========================After updates========================
# Current relations (memory_to_rank) are : [4, 5, 1, 6, 2, 3, 0]
# Current errors (td_error, index) are : [(-0.999, 6), (-0.986, 2), (-0.639, 4), (-0.523, 5), (-0.27, 0), (-0.084, 1), (-0.03, 3)]
#
# Episode 36
# Current relations (memory_to_rank) are : [0, 5, 2, 6, 3, 4, 1]
# Current errors (td_error, index) are : [(-0.999, 0), (-0.999, 6), (-0.986, 2), (-0.639, 4), (-0.523, 5), (-0.084, 1), (-0.03, 3)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [0, 2, 5] with probs [0.24888726 0.14369513 0.11130577]
# Generated TD-error : [0.519, 0.805, 0.966]
# =========================After updates========================
# Current relations (memory_to_rank) are : [4, 5, 2, 6, 3, 1, 0]
# Current errors (td_error, index) are : [(-0.999, 6), (-0.966, 5), (-0.805, 2), (-0.639, 4), (-0.519, 0), (-0.084, 1), (-0.03, 3)]
#
# Episode 37
# Current relations (memory_to_rank) are : [5, 0, 3, 6, 4, 2, 1]
# Current errors (td_error, index) are : [(-0.999, 1), (-0.999, 6), (-0.966, 5), (-0.805, 2), (-0.639, 4), (-0.519, 0), (-0.03, 3)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [6, 2, 0] with probs [0.17598987 0.12444363 0.1016078 ]
# Generated TD-error : [0.3, 0.678, 0.904]
# =========================After updates========================
# Current relations (memory_to_rank) are : [2, 0, 3, 6, 4, 1, 5]
# Current errors (td_error, index) are : [(-0.999, 1), (-0.966, 5), (-0.904, 0), (-0.678, 2), (-0.639, 4), (-0.3, 6), (-0.03, 3)]
#
# Episode 38
# Current relations (memory_to_rank) are : [3, 0, 1, 6, 4, 2, 5]
# Current errors (td_error, index) are : [(-0.999, 1), (-0.999, 2), (-0.966, 5), (-0.904, 0), (-0.639, 4), (-0.3, 6), (-0.03, 3)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [1, 5, 3] with probs [0.24888726 0.14369513 0.09407055]
# Generated TD-error : [0.428, 0.242, 0.823]
# =========================After updates========================
# Current relations (memory_to_rank) are : [1, 4, 0, 2, 3, 6, 5]
# Current errors (td_error, index) are : [(-0.999, 2), (-0.904, 0), (-0.823, 3), (-0.639, 4), (-0.428, 1), (-0.3, 6), (-0.242, 5)]
#
# Episode 39
# Current relations (memory_to_rank) are : [2, 4, 0, 1, 3, 6, 5]
# Current errors (td_error, index) are : [(-0.999, 2), (-0.999, 3), (-0.904, 0), (-0.639, 4), (-0.428, 1), (-0.3, 6), (-0.242, 5)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [2, 4, 5] with probs [0.24888726 0.12444363 0.09407055]
# Generated TD-error : [0.986, 0.724, 0.308]
# =========================After updates========================
# Current relations (memory_to_rank) are : [2, 4, 1, 0, 3, 5, 6]
# Current errors (td_error, index) are : [(-0.999, 3), (-0.986, 2), (-0.904, 0), (-0.724, 4), (-0.428, 1), (-0.308, 5), (-0.3, 6)]
#
# Episode 40
# Current relations (memory_to_rank) are : [3, 4, 2, 0, 1, 5, 6]
# Current errors (td_error, index) are : [(-0.999, 3), (-0.999, 4), (-0.986, 2), (-0.904, 0), (-0.428, 1), (-0.308, 5), (-0.3, 6)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [3, 2, 6] with probs [0.24888726 0.14369513 0.09407055]
# Generated TD-error : [0.996, 0.847, 0.079]
# =========================After updates========================
# Current relations (memory_to_rank) are : [2, 4, 3, 1, 0, 5, 6]
# Current errors (td_error, index) are : [(-0.999, 4), (-0.996, 3), (-0.904, 0), (-0.847, 2), (-0.428, 1), (-0.308, 5), (-0.079, 6)]
#
# Episode 41
# Current relations (memory_to_rank) are : [3, 5, 4, 2, 0, 1, 6]
# Current errors (td_error, index) are : [(-0.999, 4), (-0.999, 5), (-0.996, 3), (-0.904, 0), (-0.847, 2), (-0.428, 1), (-0.079, 6)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [5, 0, 2] with probs [0.17598987 0.12444363 0.11130577]
# Generated TD-error : [0.817, 0.043, 0.363]
# =========================After updates========================
# Current relations (memory_to_rank) are : [6, 3, 4, 1, 0, 2, 5]
# Current errors (td_error, index) are : [(-0.999, 4), (-0.996, 3), (-0.817, 5), (-0.428, 1), (-0.363, 2), (-0.079, 6), (-0.043, 0)]
#
# Episode 42
# Current relations (memory_to_rank) are : [6, 4, 5, 2, 0, 3, 1]
# Current errors (td_error, index) are : [(-0.999, 4), (-0.999, 6), (-0.996, 3), (-0.817, 5), (-0.428, 1), (-0.363, 2), (-0.043, 0)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [6, 5, 2] with probs [0.17598987 0.12444363 0.1016078 ]
# Generated TD-error : [0.329, 0.102, 0.475]
# =========================After updates========================
# Current relations (memory_to_rank) are : [6, 3, 2, 1, 0, 5, 4]
# Current errors (td_error, index) are : [(-0.999, 4), (-0.996, 3), (-0.475, 2), (-0.428, 1), (-0.329, 6), (-0.102, 5), (-0.043, 0)]
#
# Episode 43
# Current relations (memory_to_rank) are : [0, 4, 3, 2, 1, 6, 5]
# Current errors (td_error, index) are : [(-0.999, 0), (-0.999, 4), (-0.996, 3), (-0.475, 2), (-0.428, 1), (-0.329, 6), (-0.102, 5)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [4, 2, 5] with probs [0.17598987 0.12444363 0.09407055]
# Generated TD-error : [0.205, 0.496, 0.557]
# =========================After updates========================
# Current relations (memory_to_rank) are : [0, 4, 3, 1, 6, 2, 5]
# Current errors (td_error, index) are : [(-0.999, 0), (-0.996, 3), (-0.557, 5), (-0.496, 2), (-0.428, 1), (-0.329, 6), (-0.205, 4)]
#
# Episode 44
# Current relations (memory_to_rank) are : [0, 1, 4, 2, 6, 3, 5]
# Current errors (td_error, index) are : [(-0.999, 0), (-0.999, 1), (-0.996, 3), (-0.557, 5), (-0.496, 2), (-0.329, 6), (-0.205, 4)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [1, 3, 6] with probs [0.17598987 0.14369513 0.1016078 ]
# Generated TD-error : [0.652, 0.574, 0.805]
# =========================After updates========================
# Current relations (memory_to_rank) are : [0, 2, 5, 3, 6, 4, 1]
# Current errors (td_error, index) are : [(-0.999, 0), (-0.805, 6), (-0.652, 1), (-0.574, 3), (-0.557, 5), (-0.496, 2), (-0.205, 4)]
#
# Episode 45
# Current relations (memory_to_rank) are : [0, 3, 1, 4, 6, 5, 2]
# Current errors (td_error, index) are : [(-0.999, 0), (-0.999, 2), (-0.805, 6), (-0.652, 1), (-0.574, 3), (-0.557, 5), (-0.205, 4)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [2, 1, 4] with probs [0.17598987 0.12444363 0.09407055]
# Generated TD-error : [0.312, 0.064, 0.961]
# =========================After updates========================
# Current relations (memory_to_rank) are : [0, 6, 5, 3, 1, 4, 2]
# Current errors (td_error, index) are : [(-0.999, 0), (-0.961, 4), (-0.805, 6), (-0.574, 3), (-0.557, 5), (-0.312, 2), (-0.064, 1)]
#
# Episode 46
# Current relations (memory_to_rank) are : [0, 6, 5, 1, 2, 4, 3]
# Current errors (td_error, index) are : [(-0.999, 0), (-0.999, 3), (-0.961, 4), (-0.805, 6), (-0.557, 5), (-0.312, 2), (-0.064, 1)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [0, 6, 1] with probs [0.24888726 0.12444363 0.09407055]
# Generated TD-error : [0.216, 0.19, 0.066]
# =========================After updates========================
# Current relations (memory_to_rank) are : [4, 6, 3, 0, 1, 2, 5]
# Current errors (td_error, index) are : [(-0.999, 3), (-0.961, 4), (-0.557, 5), (-0.312, 2), (-0.216, 0), (-0.19, 6), (-0.066, 1)]
#
# Episode 47
# Current relations (memory_to_rank) are : [4, 6, 3, 0, 1, 2, 5]
# Current errors (td_error, index) are : [(-0.999, 3), (-0.999, 4), (-0.557, 5), (-0.312, 2), (-0.216, 0), (-0.19, 6), (-0.066, 1)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [3, 2, 0] with probs [0.24888726 0.12444363 0.11130577]
# Generated TD-error : [0.567, 0.385, 0.808]
# =========================After updates========================
# Current relations (memory_to_rank) are : [1, 6, 4, 2, 0, 3, 5]
# Current errors (td_error, index) are : [(-0.999, 4), (-0.808, 0), (-0.567, 3), (-0.557, 5), (-0.385, 2), (-0.19, 6), (-0.066, 1)]
#
# Episode 48
# Current relations (memory_to_rank) are : [2, 6, 4, 3, 0, 1, 5]
# Current errors (td_error, index) are : [(-0.999, 4), (-0.999, 5), (-0.808, 0), (-0.567, 3), (-0.385, 2), (-0.19, 6), (-0.066, 1)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [4, 3, 2] with probs [0.24888726 0.12444363 0.11130577]
# Generated TD-error : [0.673, 0.943, 0.495]
# =========================After updates========================
# Current relations (memory_to_rank) are : [2, 6, 4, 1, 3, 0, 5]
# Current errors (td_error, index) are : [(-0.999, 5), (-0.943, 3), (-0.808, 0), (-0.673, 4), (-0.495, 2), (-0.19, 6), (-0.066, 1)]
#
# Episode 49
# Current relations (memory_to_rank) are : [3, 6, 5, 2, 4, 0, 1]
# Current errors (td_error, index) are : [(-0.999, 5), (-0.999, 6), (-0.943, 3), (-0.808, 0), (-0.673, 4), (-0.495, 2), (-0.066, 1)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [5, 3, 2] with probs [0.24888726 0.14369513 0.1016078 ]
# Generated TD-error : [0.864, 0.973, 0.979]
# =========================After updates========================
# Current relations (memory_to_rank) are : [4, 6, 1, 2, 5, 3, 0]
# Current errors (td_error, index) are : [(-0.999, 6), (-0.979, 2), (-0.973, 3), (-0.864, 5), (-0.808, 0), (-0.673, 4), (-0.066, 1)]
#
# Episode 50
# Current relations (memory_to_rank) are : [0, 6, 2, 3, 5, 4, 1]
# Current errors (td_error, index) are : [(-0.999, 0), (-0.999, 6), (-0.979, 2), (-0.973, 3), (-0.864, 5), (-0.673, 4), (-0.066, 1)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [0, 2, 4] with probs [0.24888726 0.14369513 0.1016078 ]
# Generated TD-error : [0.88, 0.323, 0.168]
# =========================After updates========================
# Current relations (memory_to_rank) are : [2, 6, 4, 1, 5, 3, 0]
# Current errors (td_error, index) are : [(-0.999, 6), (-0.973, 3), (-0.88, 0), (-0.864, 5), (-0.323, 2), (-0.168, 4), (-0.066, 1)]
#
# Episode 51
# Current relations (memory_to_rank) are : [3, 0, 5, 2, 6, 4, 1]
# Current errors (td_error, index) are : [(-0.999, 1), (-0.999, 6), (-0.973, 3), (-0.88, 0), (-0.864, 5), (-0.323, 2), (-0.168, 4)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [6, 3, 5] with probs [0.17598987 0.14369513 0.11130577]
# Generated TD-error : [0.377, 0.607, 0.26]
# =========================After updates========================
# Current relations (memory_to_rank) are : [1, 0, 4, 2, 6, 5, 3]
# Current errors (td_error, index) are : [(-0.999, 1), (-0.88, 0), (-0.607, 3), (-0.377, 6), (-0.323, 2), (-0.26, 5), (-0.168, 4)]
#
# Episode 52
# Current relations (memory_to_rank) are : [2, 0, 1, 3, 6, 5, 4]
# Current errors (td_error, index) are : [(-0.999, 1), (-0.999, 2), (-0.88, 0), (-0.607, 3), (-0.377, 6), (-0.26, 5), (-0.168, 4)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [2, 3, 4] with probs [0.17598987 0.12444363 0.09407055]
# Generated TD-error : [0.762, 0.631, 0.59]
# =========================After updates========================
# Current relations (memory_to_rank) are : [1, 0, 2, 3, 4, 6, 5]
# Current errors (td_error, index) are : [(-0.999, 1), (-0.88, 0), (-0.762, 2), (-0.631, 3), (-0.59, 4), (-0.377, 6), (-0.26, 5)]
#
# Episode 53
# Current relations (memory_to_rank) are : [2, 0, 3, 1, 4, 6, 5]
# Current errors (td_error, index) are : [(-0.999, 1), (-0.999, 3), (-0.88, 0), (-0.762, 2), (-0.59, 4), (-0.377, 6), (-0.26, 5)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [1, 0, 5] with probs [0.24888726 0.14369513 0.09407055]
# Generated TD-error : [0.821, 0.379, 0.586]
# =========================After updates========================
# Current relations (memory_to_rank) are : [5, 1, 2, 0, 3, 4, 6]
# Current errors (td_error, index) are : [(-0.999, 3), (-0.821, 1), (-0.762, 2), (-0.59, 4), (-0.586, 5), (-0.379, 0), (-0.377, 6)]
#
# Episode 54
# Current relations (memory_to_rank) are : [5, 2, 3, 0, 1, 4, 6]
# Current errors (td_error, index) are : [(-0.999, 3), (-0.999, 4), (-0.821, 1), (-0.762, 2), (-0.586, 5), (-0.379, 0), (-0.377, 6)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [3, 1, 0] with probs [0.24888726 0.14369513 0.1016078 ]
# Generated TD-error : [0.059, 0.766, 0.65]
# =========================After updates========================
# Current relations (memory_to_rank) are : [3, 1, 2, 6, 0, 4, 5]
# Current errors (td_error, index) are : [(-0.999, 4), (-0.766, 1), (-0.762, 2), (-0.65, 0), (-0.586, 5), (-0.377, 6), (-0.059, 3)]
#
# Episode 55
# Current relations (memory_to_rank) are : [4, 2, 3, 6, 0, 1, 5]
# Current errors (td_error, index) are : [(-0.999, 4), (-0.999, 5), (-0.766, 1), (-0.762, 2), (-0.65, 0), (-0.377, 6), (-0.059, 3)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [4, 2, 3] with probs [0.24888726 0.12444363 0.09407055]
# Generated TD-error : [0.938, 0.865, 0.766]
# =========================After updates========================
# Current relations (memory_to_rank) are : [5, 3, 2, 4, 1, 0, 6]
# Current errors (td_error, index) are : [(-0.999, 5), (-0.938, 4), (-0.865, 2), (-0.766, 1), (-0.766, 3), (-0.65, 0), (-0.377, 6)]
#
# Episode 56
# Current relations (memory_to_rank) are : [6, 4, 3, 5, 2, 0, 1]
# Current errors (td_error, index) are : [(-0.999, 5), (-0.999, 6), (-0.938, 4), (-0.865, 2), (-0.766, 1), (-0.766, 3), (-0.65, 0)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [5, 2, 0] with probs [0.24888726 0.12444363 0.09407055]
# Generated TD-error : [0.382, 0.838, 0.284]
# =========================After updates========================
# Current relations (memory_to_rank) are : [6, 3, 2, 4, 1, 5, 0]
# Current errors (td_error, index) are : [(-0.999, 6), (-0.938, 4), (-0.838, 2), (-0.766, 1), (-0.766, 3), (-0.382, 5), (-0.284, 0)]
#
# Episode 57
# Current relations (memory_to_rank) are : [0, 4, 3, 5, 2, 6, 1]
# Current errors (td_error, index) are : [(-0.999, 0), (-0.999, 6), (-0.938, 4), (-0.838, 2), (-0.766, 1), (-0.766, 3), (-0.382, 5)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [0, 4, 5] with probs [0.24888726 0.14369513 0.09407055]
# Generated TD-error : [0.945, 0.163, 0.893]
# =========================After updates========================
# Current relations (memory_to_rank) are : [1, 4, 3, 5, 6, 2, 0]
# Current errors (td_error, index) are : [(-0.999, 6), (-0.945, 0), (-0.893, 5), (-0.838, 2), (-0.766, 1), (-0.766, 3), (-0.163, 4)]
#
# Episode 58
# Current relations (memory_to_rank) are : [2, 0, 4, 5, 6, 3, 1]
# Current errors (td_error, index) are : [(-0.999, 1), (-0.999, 6), (-0.945, 0), (-0.893, 5), (-0.838, 2), (-0.766, 3), (-0.163, 4)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [6, 5, 4] with probs [0.17598987 0.12444363 0.09407055]
# Generated TD-error : [0.484, 0.003, 0.6]
# ...
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [4, 5, 6] with probs [0.17598987 0.14369513 0.11130577]
# Generated TD-error : [0.091, 0.546, 0.889]
# =========================After updates========================
# Current relations (memory_to_rank) are : [4, 2, 5, 0, 6, 3, 1]
# Current errors (td_error, index) are : [(-0.999, 3), (-0.889, 6), (-0.557, 1), (-0.546, 5), (-0.155, 0), (-0.149, 2), (-0.091, 4)]
#
# Episode 83
# Current relations (memory_to_rank) are : [4, 3, 5, 0, 6, 1, 2]
# Current errors (td_error, index) are : [(-0.999, 3), (-0.999, 5), (-0.889, 6), (-0.557, 1), (-0.155, 0), (-0.149, 2), (-0.091, 4)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [3, 1, 0] with probs [0.24888726 0.12444363 0.11130577]
# Generated TD-error : [0.368, 0.913, 0.326]
# =========================After updates========================
# Current relations (memory_to_rank) are : [4, 1, 5, 3, 6, 0, 2]
# Current errors (td_error, index) are : [(-0.999, 5), (-0.913, 1), (-0.889, 6), (-0.368, 3), (-0.326, 0), (-0.149, 2), (-0.091, 4)]
#
# Episode 84
# Current relations (memory_to_rank) are : [4, 2, 5, 3, 6, 0, 1]
# Current errors (td_error, index) are : [(-0.999, 5), (-0.999, 6), (-0.913, 1), (-0.368, 3), (-0.326, 0), (-0.149, 2), (-0.091, 4)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [5, 1, 4] with probs [0.24888726 0.14369513 0.09407055]
# Generated TD-error : [0.74, 0.371, 0.818]
# =========================After updates========================
# Current relations (memory_to_rank) are : [5, 3, 6, 4, 1, 2, 0]
# Current errors (td_error, index) are : [(-0.999, 6), (-0.818, 4), (-0.74, 5), (-0.371, 1), (-0.368, 3), (-0.326, 0), (-0.149, 2)]
#
# Episode 85
# Current relations (memory_to_rank) are : [0, 4, 6, 5, 2, 3, 1]
# Current errors (td_error, index) are : [(-0.999, 0), (-0.999, 6), (-0.818, 4), (-0.74, 5), (-0.371, 1), (-0.368, 3), (-0.149, 2)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [6, 4, 2] with probs [0.17598987 0.14369513 0.09407055]
# Generated TD-error : [0.907, 0.822, 0.602]
# =========================After updates========================
# Current relations (memory_to_rank) are : [0, 5, 4, 6, 2, 3, 1]
# Current errors (td_error, index) are : [(-0.999, 0), (-0.907, 6), (-0.822, 4), (-0.74, 5), (-0.602, 2), (-0.371, 1), (-0.368, 3)]
#
# Episode 86
# Current relations (memory_to_rank) are : [0, 1, 5, 6, 3, 4, 2]
# Current errors (td_error, index) are : [(-0.999, 0), (-0.999, 1), (-0.907, 6), (-0.822, 4), (-0.74, 5), (-0.602, 2), (-0.368, 3)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [0, 4, 2] with probs [0.24888726 0.12444363 0.1016078 ]
# Generated TD-error : [0.876, 0.763, 0.612]
# =========================After updates========================
# Current relations (memory_to_rank) are : [2, 0, 5, 6, 3, 4, 1]
# Current errors (td_error, index) are : [(-0.999, 1), (-0.907, 6), (-0.876, 0), (-0.763, 4), (-0.74, 5), (-0.612, 2), (-0.368, 3)]
#
# Episode 87
# Current relations (memory_to_rank) are : [3, 0, 1, 6, 4, 5, 2]
# Current errors (td_error, index) are : [(-0.999, 1), (-0.999, 2), (-0.907, 6), (-0.876, 0), (-0.763, 4), (-0.74, 5), (-0.368, 3)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [1, 0, 5] with probs [0.24888726 0.12444363 0.1016078 ]
# Generated TD-error : [0.841, 0.629, 0.468]
# =========================After updates========================
# Current relations (memory_to_rank) are : [4, 2, 0, 6, 3, 5, 1]
# Current errors (td_error, index) are : [(-0.999, 2), (-0.907, 6), (-0.841, 1), (-0.763, 4), (-0.629, 0), (-0.468, 5), (-0.368, 3)]
#
# Episode 88
# Current relations (memory_to_rank) are : [5, 3, 0, 1, 4, 6, 2]
# Current errors (td_error, index) are : [(-0.999, 2), (-0.999, 3), (-0.907, 6), (-0.841, 1), (-0.763, 4), (-0.629, 0), (-0.468, 5)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [2, 6, 0] with probs [0.24888726 0.14369513 0.1016078 ]
# Generated TD-error : [0.166, 0.046, 0.08]
# =========================After updates========================
# Current relations (memory_to_rank) are : [5, 1, 4, 0, 2, 3, 6]
# Current errors (td_error, index) are : [(-0.999, 3), (-0.841, 1), (-0.763, 4), (-0.468, 5), (-0.166, 2), (-0.08, 0), (-0.046, 6)]
#
# Episode 89
# Current relations (memory_to_rank) are : [5, 2, 4, 0, 1, 3, 6]
# Current errors (td_error, index) are : [(-0.999, 3), (-0.999, 4), (-0.841, 1), (-0.468, 5), (-0.166, 2), (-0.08, 0), (-0.046, 6)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [3, 1, 0] with probs [0.24888726 0.14369513 0.1016078 ]
# Generated TD-error : [0.231, 0.871, 0.524]
# =========================After updates========================
# Current relations (memory_to_rank) are : [2, 1, 5, 4, 0, 3, 6]
# Current errors (td_error, index) are : [(-0.999, 4), (-0.871, 1), (-0.524, 0), (-0.468, 5), (-0.231, 3), (-0.166, 2), (-0.046, 6)]
#
# Episode 90
# Current relations (memory_to_rank) are : [3, 2, 5, 4, 0, 1, 6]
# Current errors (td_error, index) are : [(-0.999, 4), (-0.999, 5), (-0.871, 1), (-0.524, 0), (-0.231, 3), (-0.166, 2), (-0.046, 6)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [4, 1, 3] with probs [0.24888726 0.14369513 0.11130577]
# Generated TD-error : [0.74, 0.875, 0.058]
# =========================After updates========================
# Current relations (memory_to_rank) are : [3, 1, 4, 5, 2, 0, 6]
# Current errors (td_error, index) are : [(-0.999, 5), (-0.875, 1), (-0.74, 4), (-0.524, 0), (-0.166, 2), (-0.058, 3), (-0.046, 6)]
#
# Episode 91
# Current relations (memory_to_rank) are : [4, 2, 5, 6, 3, 0, 1]
# Current errors (td_error, index) are : [(-0.999, 5), (-0.999, 6), (-0.875, 1), (-0.74, 4), (-0.524, 0), (-0.166, 2), (-0.058, 3)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [5, 1, 2] with probs [0.24888726 0.14369513 0.1016078 ]
# Generated TD-error : [0.035, 0.545, 0.328]
# =========================After updates========================
# Current relations (memory_to_rank) are : [3, 2, 4, 5, 1, 6, 0]
# Current errors (td_error, index) are : [(-0.999, 6), (-0.74, 4), (-0.545, 1), (-0.524, 0), (-0.328, 2), (-0.058, 3), (-0.035, 5)]
#
# Episode 92
# Current relations (memory_to_rank) are : [0, 3, 4, 5, 2, 6, 1]
# Current errors (td_error, index) are : [(-0.999, 0), (-0.999, 6), (-0.74, 4), (-0.545, 1), (-0.328, 2), (-0.058, 3), (-0.035, 5)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [6, 1, 3] with probs [0.17598987 0.12444363 0.1016078 ]
# Generated TD-error : [0.133, 0.871, 0.195]
# =========================After updates========================
# Current relations (memory_to_rank) are : [0, 1, 3, 4, 2, 6, 5]
# Current errors (td_error, index) are : [(-0.999, 0), (-0.871, 1), (-0.74, 4), (-0.328, 2), (-0.195, 3), (-0.133, 6), (-0.035, 5)]
#
# Episode 93
# Current relations (memory_to_rank) are : [0, 1, 3, 4, 2, 6, 5]
# Current errors (td_error, index) are : [(-0.999, 0), (-0.999, 1), (-0.74, 4), (-0.328, 2), (-0.195, 3), (-0.133, 6), (-0.035, 5)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [0, 4, 3] with probs [0.24888726 0.14369513 0.11130577]
# Generated TD-error : [0.844, 0.277, 0.565]
# =========================After updates========================
# Current relations (memory_to_rank) are : [1, 0, 3, 2, 4, 6, 5]
# Current errors (td_error, index) are : [(-0.999, 1), (-0.844, 0), (-0.565, 3), (-0.328, 2), (-0.277, 4), (-0.133, 6), (-0.035, 5)]
#
# Episode 94
# Current relations (memory_to_rank) are : [2, 0, 1, 3, 4, 6, 5]
# Current errors (td_error, index) are : [(-0.999, 1), (-0.999, 2), (-0.844, 0), (-0.565, 3), (-0.277, 4), (-0.133, 6), (-0.035, 5)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [1, 0, 4] with probs [0.24888726 0.14369513 0.11130577]
# Generated TD-error : [0.307, 0.597, 0.234]
# =========================After updates========================
# Current relations (memory_to_rank) are : [1, 3, 0, 2, 4, 6, 5]
# Current errors (td_error, index) are : [(-0.999, 2), (-0.597, 0), (-0.565, 3), (-0.307, 1), (-0.234, 4), (-0.133, 6), (-0.035, 5)]
#
# Episode 95
# Current relations (memory_to_rank) are : [2, 3, 0, 1, 4, 6, 5]
# Current errors (td_error, index) are : [(-0.999, 2), (-0.999, 3), (-0.597, 0), (-0.307, 1), (-0.234, 4), (-0.133, 6), (-0.035, 5)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [2, 0, 5] with probs [0.24888726 0.14369513 0.09407055]
# Generated TD-error : [0.571, 0.256, 0.534]
# =========================After updates========================
# Current relations (memory_to_rank) are : [4, 3, 1, 0, 5, 2, 6]
# Current errors (td_error, index) are : [(-0.999, 3), (-0.571, 2), (-0.534, 5), (-0.307, 1), (-0.256, 0), (-0.234, 4), (-0.133, 6)]
#
# Episode 96
# Current relations (memory_to_rank) are : [5, 4, 2, 0, 1, 3, 6]
# Current errors (td_error, index) are : [(-0.999, 3), (-0.999, 4), (-0.571, 2), (-0.534, 5), (-0.307, 1), (-0.256, 0), (-0.133, 6)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [4, 2, 0] with probs [0.17598987 0.14369513 0.1016078 ]
# Generated TD-error : [0.946, 0.271, 0.143]
# =========================After updates========================
# Current relations (memory_to_rank) are : [5, 3, 4, 0, 1, 2, 6]
# Current errors (td_error, index) are : [(-0.999, 3), (-0.946, 4), (-0.534, 5), (-0.307, 1), (-0.271, 2), (-0.143, 0), (-0.133, 6)]
#
# Episode 97
# Current relations (memory_to_rank) are : [5, 3, 4, 0, 2, 1, 6]
# Current errors (td_error, index) are : [(-0.999, 3), (-0.999, 5), (-0.946, 4), (-0.307, 1), (-0.271, 2), (-0.143, 0), (-0.133, 6)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [5, 1, 0] with probs [0.17598987 0.12444363 0.1016078 ]
# Generated TD-error : [0.357, 0.418, 0.811]
# =========================After updates========================
# Current relations (memory_to_rank) are : [2, 3, 5, 0, 1, 4, 6]
# Current errors (td_error, index) are : [(-0.999, 3), (-0.946, 4), (-0.811, 0), (-0.418, 1), (-0.357, 5), (-0.271, 2), (-0.133, 6)]
#
# Episode 98
# Current relations (memory_to_rank) are : [3, 4, 6, 0, 2, 5, 1]
# Current errors (td_error, index) are : [(-0.999, 3), (-0.999, 6), (-0.946, 4), (-0.811, 0), (-0.418, 1), (-0.357, 5), (-0.271, 2)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [6, 0, 2] with probs [0.17598987 0.12444363 0.09407055]
# Generated TD-error : [0.371, 0.887, 0.79]
# =========================After updates========================
# Current relations (memory_to_rank) are : [2, 4, 3, 0, 1, 6, 5]
# Current errors (td_error, index) are : [(-0.999, 3), (-0.946, 4), (-0.887, 0), (-0.79, 2), (-0.418, 1), (-0.371, 6), (-0.357, 5)]
#
# Episode 99
# Current relations (memory_to_rank) are : [0, 4, 3, 1, 2, 6, 5]
# Current errors (td_error, index) are : [(-0.999, 0), (-0.999, 3), (-0.946, 4), (-0.79, 2), (-0.418, 1), (-0.371, 6), (-0.357, 5)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [0, 4, 5] with probs [0.24888726 0.14369513 0.09407055]
# Generated TD-error : [0.972, 0.644, 0.281]
# =========================After updates========================
# Current relations (memory_to_rank) are : [1, 4, 2, 0, 3, 6, 5]
# Current errors (td_error, index) are : [(-0.999, 3), (-0.972, 0), (-0.79, 2), (-0.644, 4), (-0.418, 1), (-0.371, 6), (-0.281, 5)]
#
# Episode 100
# Current relations (memory_to_rank) are : [2, 0, 3, 1, 4, 6, 5]
# Current errors (td_error, index) are : [(-0.999, 1), (-0.999, 3), (-0.972, 0), (-0.79, 2), (-0.644, 4), (-0.371, 6), (-0.281, 5)]
# Current segment weights are : [1.3392944697830738, 2.6785889395661475, 4.0178834093492215]
# Current cumulated sums are : [1.0, 1.7071067811865475, 2.284457050376173, 2.784457050376173, 3.231670645876131, 3.639918936339994, 4.0178834093492215]
# Current segment is : [-1, 1, 3, 6]
# Sampled transitions [1, 2, 5] with probs [0.24888726 0.12444363 0.09407055]
# Generated TD-error : [0.936, 0.525, 0.687]
# =========================After updates========================
# Current relations (memory_to_rank) are : [1, 2, 5, 0, 4, 3, 6]
# Current errors (td_error, index) are : [(-0.999, 3), (-0.972, 0), (-0.936, 1), (-0.687, 5), (-0.644, 4), (-0.525, 2), (-0.371, 6)]
